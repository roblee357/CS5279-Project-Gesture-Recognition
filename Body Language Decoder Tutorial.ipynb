# %% [markdown]
# # 0. Install and Import Dependencies

# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (0.8.4.2)
# Requirement already satisfied: opencv-python in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (4.3.0.36)
# Requirement already satisfied: pandas in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (1.0.5)
# Requirement already satisfied: scikit-learn in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (0.23.1)
# Requirement already satisfied: protobuf>=3.11.4 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (3.12.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (4.5.2.52)
# Requirement already satisfied: wheel in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (0.34.2)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (19.3.0)
# Requirement already satisfied: six in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (1.15.0)
# Requirement already satisfied: numpy in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (1.19.0)
# Requirement already satisfied: absl-py in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (0.9.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (0.16.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: setuptools in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from protobuf>=3.11.4->mediapipe) (41.2.0)
# The system cannot find the path specified.
# WARNING: You are using pip version 20.2.4; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\roble\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Make Some Detections

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e9b3666ae3b4> in <module>
#       4
#       5     while cap.isOpened():
# ----> 6         ret, frame = cap.read()
#       7
#       8         # Recolor Feed
#
# KeyboardInterrupt:

# %% [markdown]
# # 2. Capture Landmarks & Export to CSV
# <!--<img src="https://i.imgur.com/8bForKY.png">-->
# <!--<img src="https://i.imgur.com/AzKNp7A.png">-->

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d533906b7cf0> in <module>
#       1 landmarks = ['class']
# ----> 2 for val in range(1, num_coords+1):
#       3     landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]
#
# NameError: name 'num_coords' is not defined

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "Sad"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
                # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            # Concate rows
            row = pose_row+face_row

            # Append class name 
            row.insert(0, class_name)

            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 

        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-e351fd29a860> in <module>
#       7
#       8         # Recolor Feed
# ----> 9         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      10         image.flags.writeable = False
#      11
#
# error: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-kuwfz3h3\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import pafy, cv2
#url = 'https://youtu.be/DK797d9ozN0?t=440'
#url = 'https://www.youtube.com/watch?v=nMB5CtphAVo'
url =  'https://www.youtube.com/watch?v=ZrOWy6UxADc'
vPafy = pafy.new(url)
play = vPafy.getbest(preftype="mp4")

#start the video
cap = cv2.VideoCapture(play.url)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while (True):
            ret, frame = cap.read()

            # Recolor Feed
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False        

            # Make Detections
            results = holistic.process(image)
            # print(results.face_landmarks)

            # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks

            # Recolor image back to BGR for rendering
            image.flags.writeable = True   
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 1. Draw face landmarks
            mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                     mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                     )

            # 2. Right hand
            mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                     mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                     )

            # 3. Left Hand
            mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                     mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                     )

            # 4. Pose Detections
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                     mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                     )
            # Export coordinates
            try:
                    # Extract Pose landmarks
                pose = results.pose_landmarks.landmark
                pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

                # Extract Face landmarks
                face = results.face_landmarks.landmark
                face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

                # Concate rows
                row = pose_row+face_row

                # Append class name 
                row.insert(0, class_name)

                # Export to CSV
                with open('coords.csv', mode='a', newline='') as f:
                    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    csv_writer.writerow(row) 

            except:
                pass

            cv2.imshow('Raw Webcam Feed', image)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break  

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-36c51fd9a814> in <module>
#      13
#      14             # Recolor Feed
# ---> 15             image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      16             image.flags.writeable = False
#      17
#
# error: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-kuwfz3h3\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# # 3. Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#              class        x1        y1        z1        v1        x2  \
# 0  Wakanda Forever  0.540143  0.089266 -0.714906  0.997470  0.582785
# 1  Wakanda Forever  0.542138  0.090656 -0.713699  0.997034  0.583193
# 2  Wakanda Forever  0.546151  0.090654 -0.621923  0.996671  0.586127
# 3  Wakanda Forever  0.546029  0.090903 -0.640098  0.996718  0.585790
# 4  Wakanda Forever  0.547212  0.090917 -0.652977  0.996647  0.586384
#
#          y2        z2        v2        x3  ...      z499  v499      x500  \
# 0  0.033290 -0.654591  0.997805  0.602898  ... -0.018422   0.0  0.610509
# 1  0.035839 -0.654409  0.997408  0.603308  ... -0.018842   0.0  0.620125
# 2  0.037953 -0.562781  0.997071  0.605997  ... -0.019170   0.0  0.626131
# 3  0.038489 -0.577144  0.997132  0.605627  ... -0.019241   0.0  0.621527
# 4  0.038508 -0.595775  0.997098  0.606010  ... -0.019219   0.0  0.619078
#
#        y500      z500  v500      x501      y501      z501  v501
# 0  0.022507 -0.012553   0.0  0.616505  0.013975 -0.013144   0.0
# 1  0.013244 -0.009857   0.0  0.625721  0.005837 -0.010236   0.0
# 2  0.017769 -0.009852   0.0  0.631628  0.010429 -0.010203   0.0
# 3  0.020974 -0.010625   0.0  0.626714  0.013748 -0.011079   0.0
# 4  0.016577 -0.010582   0.0  0.624074  0.009527 -0.011055   0.0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#     class        x1        y1        z1        v1        x2        y2  \
# 419   Sad  0.532784  0.262628 -0.964621  0.999033  0.578204  0.188125
# 420   Sad  0.531995  0.252105 -0.901582  0.999071  0.575930  0.180767
# 421   Sad  0.525418  0.247770 -0.872912  0.999130  0.565986  0.175307
# 422   Sad  0.502427  0.261909 -0.773343  0.999178  0.529863  0.184474
# 423   Sad  0.473356  0.275888 -0.619453  0.999114  0.488427  0.198840
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 419 -0.950985  0.998691  0.604016  ... -0.040297   0.0  0.613725  0.196481
# 420 -0.896354  0.998676  0.600612  ... -0.039297   0.0  0.604650  0.184573
# 421 -0.884153  0.998732  0.588979  ... -0.038676   0.0  0.595926  0.191943
# 422 -0.806856  0.998735  0.548305  ... -0.037956   0.0  0.588393  0.199763
# 423 -0.677360  0.998526  0.503742  ... -0.011923   0.0  0.556528  0.172266
#
#          z500  v500      x501      y501      z501  v501
# 419 -0.065941   0.0  0.620482  0.186376 -0.069414   0.0
# 420 -0.069129   0.0  0.611524  0.174184 -0.073023   0.0
# 421 -0.070000   0.0  0.602476  0.181570 -0.074200   0.0
# 422 -0.072216   0.0  0.593654  0.186191 -0.076753   0.0
# 423 -0.033000   0.0  0.560332  0.163414 -0.035986   0.0
#
# [5 rows x 2005 columns]

# %%
df[df['class']=='Sad']
# Out:
#     class        x1        y1        z1        v1        x2        y2  \
# 395   Sad  0.477412  0.397933 -1.006443  0.999881  0.514526  0.302290
# 396   Sad  0.478443  0.384534 -1.007964  0.999887  0.515353  0.284258
# 397   Sad  0.480302  0.372612 -1.029168  0.999894  0.516466  0.272136
# 398   Sad  0.480291  0.355528 -1.034493  0.999900  0.516341  0.258996
# 399   Sad  0.481704  0.354064 -1.010464  0.999903  0.517980  0.257181
# 400   Sad  0.481705  0.347304 -0.985690  0.999903  0.517733  0.249136
# 401   Sad  0.495802  0.348216 -1.087783  0.999891  0.530432  0.250396
# 402   Sad  0.496378  0.351155 -1.083189  0.999884  0.530422  0.253453
# 403   Sad  0.500675  0.356911 -1.074444  0.999872  0.531903  0.259142
# 404   Sad  0.772676  0.689898 -1.707047  0.989329  0.798930  0.623229
# 405   Sad  0.392707  0.510667 -1.000794  0.995019  0.415522  0.437295
# 406   Sad  0.398007  0.510608 -1.021940  0.995470  0.418481  0.436045
# 407   Sad  0.415006  0.453714 -1.167536  0.996483  0.428830  0.367153
# 408   Sad  0.440159  0.341818 -0.941630  0.997332  0.479954  0.261961
# 409   Sad  0.452370  0.329604 -0.845211  0.997579  0.496415  0.249866
# 410   Sad  0.462967  0.303111 -0.750320  0.997805  0.506956  0.230270
# 411   Sad  0.463348  0.296345 -0.872924  0.998001  0.508519  0.224374
# 412   Sad  0.475754  0.281794 -0.853439  0.998177  0.520692  0.211599
# 413   Sad  0.481417  0.274341 -0.841368  0.998343  0.524434  0.203774
# 414   Sad  0.483090  0.269132 -0.880040  0.998478  0.530094  0.196639
# 415   Sad  0.491852  0.259770 -0.869250  0.998614  0.539054  0.186152
# 416   Sad  0.514977  0.256919 -0.885586  0.998738  0.561160  0.185579
# 417   Sad  0.522851  0.262268 -0.982214  0.998853  0.570197  0.188736
# 418   Sad  0.532728  0.258984 -1.002936  0.998940  0.580257  0.183777
# 419   Sad  0.532784  0.262628 -0.964621  0.999033  0.578204  0.188125
# 420   Sad  0.531995  0.252105 -0.901582  0.999071  0.575930  0.180767
# 421   Sad  0.525418  0.247770 -0.872912  0.999130  0.565986  0.175307
# 422   Sad  0.502427  0.261909 -0.773343  0.999178  0.529863  0.184474
# 423   Sad  0.473356  0.275888 -0.619453  0.999114  0.488427  0.198840
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 395 -1.042656  0.999796  0.546139  ... -0.057026   0.0  0.581863  0.295337
# 396 -1.039986  0.999806  0.547324  ... -0.053036   0.0  0.579123  0.270936
# 397 -1.047566  0.999818  0.548193  ... -0.052998   0.0  0.583771  0.255632
# 398 -1.048007  0.999828  0.547913  ... -0.055042   0.0  0.585031  0.249124
# 399 -1.022817  0.999832  0.549207  ... -0.056064   0.0  0.583015  0.257032
# 400 -1.000582  0.999830  0.548792  ... -0.053149   0.0  0.581640  0.264220
# 401 -1.089460  0.999802  0.559458  ... -0.052652   0.0  0.576927  0.269667
# 402 -1.088117  0.999785  0.559326  ... -0.050882   0.0  0.572859  0.279780
# 403 -1.088658  0.999753  0.560065  ... -0.048737   0.0  0.567929  0.280620
# 404 -1.701647  0.986947  0.806380  ... -0.026375   0.0  0.798947  0.360514
# 405 -1.096962  0.993718  0.431091  ... -0.016855   0.0  0.606319  0.523008
# 406 -1.114031  0.994291  0.434069  ... -0.024983   0.0  0.628318  0.494549
# 407 -1.212434  0.995591  0.446262  ... -0.042485   0.0  0.562990  0.288292
# 408 -0.968177  0.996642  0.505269  ... -0.047344   0.0  0.569859  0.249244
# 409 -0.869558  0.996946  0.521353  ... -0.043233   0.0  0.564598  0.246299
# 410 -0.779104  0.997221  0.529819  ... -0.039526   0.0  0.560439  0.239337
# 411 -0.906741  0.997460  0.531623  ... -0.042433   0.0  0.564158  0.231725
# 412 -0.879597  0.997669  0.544492  ... -0.039749   0.0  0.562680  0.221576
# 413 -0.867280  0.997873  0.547432  ... -0.043608   0.0  0.571084  0.216259
# 414 -0.914965  0.998035  0.554693  ... -0.042867   0.0  0.571936  0.213401
# 415 -0.889414  0.998202  0.564589  ... -0.045972   0.0  0.586208  0.213767
# 416 -0.901023  0.998349  0.586499  ... -0.049029   0.0  0.610676  0.203228
# 417 -0.985891  0.998491  0.596385  ... -0.046530   0.0  0.621120  0.208186
# 418 -0.997288  0.998580  0.607341  ... -0.042591   0.0  0.617965  0.205152
# 419 -0.950985  0.998691  0.604016  ... -0.040297   0.0  0.613725  0.196481
# 420 -0.896354  0.998676  0.600612  ... -0.039297   0.0  0.604650  0.184573
# 421 -0.884153  0.998732  0.588979  ... -0.038676   0.0  0.595926  0.191943
# 422 -0.806856  0.998735  0.548305  ... -0.037956   0.0  0.588393  0.199763
# 423 -0.677360  0.998526  0.503742  ... -0.011923   0.0  0.556528  0.172266
#
#          z500  v500      x501      y501      z501  v501
# 395 -0.073815   0.0  0.588229  0.281970 -0.077252   0.0
# 396 -0.070991   0.0  0.584971  0.257623 -0.074169   0.0
# 397 -0.070352   0.0  0.589614  0.243063 -0.073603   0.0
# 398 -0.068787   0.0  0.590742  0.237469 -0.071811   0.0
# 399 -0.070718   0.0  0.588884  0.245575 -0.073817   0.0
# 400 -0.067355   0.0  0.587434  0.252211 -0.070347   0.0
# 401 -0.067214   0.0  0.582512  0.257134 -0.070197   0.0
# 402 -0.064625   0.0  0.578017  0.267973 -0.067505   0.0
# 403 -0.063259   0.0  0.572761  0.268815 -0.066124   0.0
# 404 -0.030677   0.0  0.812172  0.354788 -0.033444   0.0
# 405 -0.019504   0.0  0.617872  0.524821 -0.020533   0.0
# 406 -0.025050   0.0  0.641740  0.496816 -0.025972   0.0
# 407 -0.063202   0.0  0.567165  0.271490 -0.066441   0.0
# 408 -0.080131   0.0  0.577513  0.237868 -0.084823   0.0
# 409 -0.075507   0.0  0.572068  0.235027 -0.079704   0.0
# 410 -0.071498   0.0  0.567978  0.227202 -0.075523   0.0
# 411 -0.075575   0.0  0.571804  0.219543 -0.079726   0.0
# 412 -0.071450   0.0  0.570005  0.209783 -0.075509   0.0
# 413 -0.075979   0.0  0.578492  0.205421 -0.080228   0.0
# 414 -0.075899   0.0  0.579084  0.202603 -0.080145   0.0
# 415 -0.075272   0.0  0.593612  0.203099 -0.079240   0.0
# 416 -0.076711   0.0  0.617438  0.192318 -0.080674   0.0
# 417 -0.070744   0.0  0.627682  0.198538 -0.074403   0.0
# 418 -0.067040   0.0  0.624615  0.195249 -0.070620   0.0
# 419 -0.065941   0.0  0.620482  0.186376 -0.069414   0.0
# 420 -0.069129   0.0  0.611524  0.174184 -0.073023   0.0
# 421 -0.070000   0.0  0.602476  0.181570 -0.074200   0.0
# 422 -0.072216   0.0  0.593654  0.186191 -0.076753   0.0
# 423 -0.033000   0.0  0.560332  0.163414 -0.035986   0.0
#
# [29 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 283        Surfer Dude
# 7      Wakanda Forever
# 268        Surfer Dude
# 213        Surfer Dude
# 239        Surfer Dude
#             ...
# 67     Wakanda Forever
# 348              Happy
# 193        Surfer Dude
# 402                Sad
# 411                Sad
# Name: class, Length: 128, dtype: object

# %% [markdown]
# ## 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# c:\users\roble\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Surfer Dude', 'Wakanda Forever', 'Surfer Dude', 'Surfer Dude',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Wakanda Forever',
#        'Surfer Dude', 'Happy', 'Surfer Dude', 'Wakanda Forever', 'Happy',
#        'Happy', 'Happy', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Sad', 'Wakanda Forever', 'Surfer Dude', 'Surfer Dude', 'Happy',
#        'Surfer Dude', 'Happy', 'Happy', 'Surfer Dude', 'Wakanda Forever',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever',
#        'Surfer Dude', 'Wakanda Forever', 'Happy', 'Wakanda Forever',
#        'Happy', 'Happy', 'Happy', 'Surfer Dude', 'Surfer Dude',
#        'Surfer Dude', 'Wakanda Forever', 'Sad', 'Wakanda Forever',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Wakanda Forever', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Wakanda Forever', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Happy', 'Happy',
#        'Wakanda Forever', 'Surfer Dude', 'Wakanda Forever', 'Surfer Dude',
#        'Happy', 'Happy', 'Sad', 'Happy', 'Happy', 'Surfer Dude', 'Happy',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Wakanda Forever',
#        'Happy', 'Happy', 'Happy', 'Surfer Dude', 'Happy',
#        'Wakanda Forever', 'Surfer Dude', 'Happy', 'Surfer Dude',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Happy',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Happy',
#        'Surfer Dude', 'Sad', 'Surfer Dude', 'Happy', 'Surfer Dude',
#        'Wakanda Forever', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Sad', 'Happy', 'Wakanda Forever', 'Surfer Dude', 'Surfer Dude',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Wakanda Forever',
#        'Happy', 'Surfer Dude', 'Wakanda Forever', 'Surfer Dude', 'Happy',
#        'Surfer Dude', 'Wakanda Forever', 'Surfer Dude', 'Wakanda Forever',
#        'Happy', 'Surfer Dude', 'Sad', 'Sad'], dtype='<U15')

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9921875
# rc 1.0
# rf 0.9921875
# gb 0.9921875

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Surfer Dude', 'Wakanda Forever', 'Surfer Dude', 'Surfer Dude',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Wakanda Forever',
#        'Surfer Dude', 'Happy', 'Surfer Dude', 'Wakanda Forever', 'Happy',
#        'Happy', 'Happy', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Sad', 'Wakanda Forever', 'Surfer Dude', 'Surfer Dude', 'Happy',
#        'Surfer Dude', 'Happy', 'Happy', 'Surfer Dude', 'Wakanda Forever',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever',
#        'Surfer Dude', 'Wakanda Forever', 'Happy', 'Wakanda Forever',
#        'Happy', 'Happy', 'Happy', 'Surfer Dude', 'Surfer Dude',
#        'Surfer Dude', 'Wakanda Forever', 'Sad', 'Wakanda Forever',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Wakanda Forever', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Wakanda Forever', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Happy', 'Happy',
#        'Wakanda Forever', 'Surfer Dude', 'Wakanda Forever', 'Surfer Dude',
#        'Happy', 'Happy', 'Sad', 'Happy', 'Happy', 'Surfer Dude', 'Happy',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Wakanda Forever',
#        'Happy', 'Happy', 'Happy', 'Surfer Dude', 'Happy',
#        'Wakanda Forever', 'Surfer Dude', 'Happy', 'Surfer Dude',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Happy',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Happy',
#        'Surfer Dude', 'Sad', 'Surfer Dude', 'Happy', 'Surfer Dude',
#        'Wakanda Forever', 'Surfer Dude', 'Surfer Dude', 'Surfer Dude',
#        'Happy', 'Happy', 'Wakanda Forever', 'Surfer Dude', 'Surfer Dude',
#        'Surfer Dude', 'Surfer Dude', 'Surfer Dude', 'Wakanda Forever',
#        'Happy', 'Surfer Dude', 'Wakanda Forever', 'Surfer Dude', 'Happy',
#        'Surfer Dude', 'Wakanda Forever', 'Surfer Dude', 'Wakanda Forever',
#        'Happy', 'Surfer Dude', 'Sad', 'Sad'], dtype=object)

# %%
y_test
# Out:
# 283        Surfer Dude
# 7      Wakanda Forever
# 268        Surfer Dude
# 213        Surfer Dude
# 239        Surfer Dude
#             ...
# 67     Wakanda Forever
# 348              Happy
# 193        Surfer Dude
# 402                Sad
# 411                Sad
# Name: class, Length: 128, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # 4. Make Detections with Model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Sad [0.13 0.47 0.05 0.35]
# Sad [0.13 0.49 0.06 0.32]
# Sad [0.14 0.49 0.07 0.3 ]
# Sad [0.1  0.56 0.06 0.28]
# Sad [0.14 0.55 0.05 0.26]
# Sad [0.12 0.67 0.05 0.16]
# Sad [0.07 0.76 0.04 0.13]
# Sad [0.01 0.77 0.07 0.15]
# Sad [0.01 0.51 0.06 0.42]
# Sad [0.03 0.46 0.11 0.4 ]
# Sad [0.33 0.48 0.07 0.12]
# Sad [0.09 0.51 0.08 0.32]
# Sad [0.29 0.41 0.09 0.21]
# Wakanda Forever [0.   0.43 0.06 0.51]
# Wakanda Forever [0.01 0.3  0.2  0.49]
# Wakanda Forever [0.   0.25 0.18 0.57]
# Wakanda Forever [0.  0.1 0.2 0.7]
# Wakanda Forever [0.01 0.1  0.26 0.63]
# Wakanda Forever [0.01 0.1  0.24 0.65]
# Wakanda Forever [0.01 0.07 0.27 0.65]
# Wakanda Forever [0.   0.11 0.24 0.65]
# Surfer Dude [0.   0.09 0.46 0.45]
# Wakanda Forever [0.   0.14 0.41 0.45]
# Wakanda Forever [0.   0.13 0.4  0.47]
# Surfer Dude [0.   0.04 0.77 0.19]
# Wakanda Forever [0.   0.08 0.37 0.55]
# Wakanda Forever [0.   0.06 0.43 0.51]
# Wakanda Forever [0.   0.05 0.42 0.53]
# Wakanda Forever [0.   0.06 0.42 0.52]
# Wakanda Forever [0.   0.06 0.45 0.49]
# Surfer Dude [0.   0.07 0.59 0.34]
# Surfer Dude [0.   0.08 0.54 0.38]
# Surfer Dude [0.   0.04 0.55 0.41]
# Surfer Dude [0.   0.06 0.5  0.44]
# Surfer Dude [0.   0.12 0.51 0.37]
# Surfer Dude [0.   0.12 0.45 0.43]
# Surfer Dude [0.   0.16 0.45 0.39]
# Surfer Dude [0.04 0.18 0.39 0.39]
# Surfer Dude [0.01 0.12 0.48 0.39]
# Surfer Dude [0.01 0.12 0.48 0.39]
# Surfer Dude [0.01 0.1  0.52 0.37]
# Surfer Dude [0.01 0.07 0.58 0.34]
# Surfer Dude [0.   0.06 0.6  0.34]
# Surfer Dude [0.   0.04 0.65 0.31]
# Surfer Dude [0.   0.02 0.87 0.11]
# Surfer Dude [0.   0.03 0.79 0.18]
# Surfer Dude [0.   0.1  0.59 0.31]
# Surfer Dude [0.  0.1 0.6 0.3]
# Surfer Dude [0.   0.1  0.61 0.29]
# Surfer Dude [0.   0.1  0.62 0.28]
# Surfer Dude [0.   0.12 0.48 0.4 ]
# Surfer Dude [0.   0.12 0.51 0.37]
# Surfer Dude [0.   0.13 0.51 0.36]
# Surfer Dude [0.   0.1  0.54 0.36]
# Surfer Dude [0.   0.12 0.49 0.39]
# Surfer Dude [0.   0.19 0.53 0.28]
# Surfer Dude [0.   0.09 0.58 0.33]
# Surfer Dude [0.   0.1  0.57 0.33]
# Surfer Dude [0.   0.09 0.59 0.32]
# Surfer Dude [0.   0.14 0.57 0.29]
# Surfer Dude [0.12 0.25 0.41 0.22]
# Surfer Dude [0.03 0.27 0.38 0.32]
# Surfer Dude [0.   0.26 0.37 0.37]
# Wakanda Forever [0.03 0.11 0.33 0.53]
# Surfer Dude [0.03 0.04 0.6  0.33]
# Surfer Dude [0.02 0.09 0.6  0.29]
# Surfer Dude [0.01 0.09 0.65 0.25]
# Surfer Dude [0.   0.06 0.74 0.2 ]
# Surfer Dude [0.   0.06 0.76 0.18]
# Surfer Dude [0.   0.04 0.74 0.22]
# Surfer Dude [0.   0.06 0.73 0.21]
# Surfer Dude [0.   0.06 0.69 0.25]
# Surfer Dude [0.   0.06 0.67 0.27]
# Surfer Dude [0.   0.07 0.67 0.26]
# Surfer Dude [0.   0.05 0.7  0.25]
# Surfer Dude [0.   0.05 0.69 0.26]
# Surfer Dude [0.   0.06 0.67 0.27]
# Surfer Dude [0.   0.05 0.68 0.27]
# Surfer Dude [0.   0.05 0.69 0.26]
# Surfer Dude [0.   0.05 0.69 0.26]
# Surfer Dude [0.   0.05 0.7  0.25]
# Surfer Dude [0.   0.01 0.65 0.34]
# Surfer Dude [0.01 0.03 0.61 0.35]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.02 0.89 0.09]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.01 0.85 0.14]
# Surfer Dude [0.   0.   0.89 0.11]
# Surfer Dude [0.   0.01 0.93 0.06]
# Surfer Dude [0.   0.02 0.89 0.09]
# Surfer Dude [0.   0.01 0.92 0.07]
# Surfer Dude [0.   0.02 0.9  0.08]
# Surfer Dude [0.   0.01 0.93 0.06]
# Surfer Dude [0.   0.02 0.92 0.06]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.05 0.09 0.75 0.11]
# Surfer Dude [0.01 0.07 0.8  0.12]
# Surfer Dude [0.   0.01 0.92 0.07]
# Surfer Dude [0.   0.01 0.93 0.06]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.   0.01 0.93 0.06]
# Surfer Dude [0.   0.01 0.93 0.06]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.92 0.07]
# Surfer Dude [0.   0.01 0.93 0.06]
# Surfer Dude [0.   0.01 0.94 0.05]
# Surfer Dude [0.   0.01 0.94 0.05]
# Surfer Dude [0.   0.01 0.94 0.05]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.   0.   0.95 0.05]
# Surfer Dude [0.   0.   0.95 0.05]
# Surfer Dude [0.   0.   0.95 0.05]
# Surfer Dude [0.   0.   0.95 0.05]
# Surfer Dude [0.   0.   0.95 0.05]
# Surfer Dude [0.   0.   0.95 0.05]
# Surfer Dude [0.   0.   0.95 0.05]
# Surfer Dude [0.   0.   0.95 0.05]
# Surfer Dude [0.   0.   0.96 0.04]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.   0.   0.95 0.05]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.02 0.85 0.13]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.84 0.13]
# Surfer Dude [0.   0.02 0.86 0.12]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.85 0.14]
# Surfer Dude [0.   0.01 0.85 0.14]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.86 0.13]
# Surfer Dude [0.   0.01 0.86 0.13]
# Surfer Dude [0.   0.01 0.83 0.16]
# Surfer Dude [0.   0.01 0.85 0.14]
# Surfer Dude [0.   0.01 0.85 0.14]
# Surfer Dude [0.   0.01 0.84 0.15]
# Surfer Dude [0.   0.01 0.86 0.13]
# Surfer Dude [0.   0.02 0.86 0.12]
# Surfer Dude [0.   0.02 0.86 0.12]
# Surfer Dude [0.   0.02 0.86 0.12]
# Surfer Dude [0.   0.02 0.85 0.13]
# Surfer Dude [0.   0.02 0.86 0.12]
# Surfer Dude [0.   0.02 0.84 0.14]
# Surfer Dude [0.   0.02 0.83 0.15]
# Surfer Dude [0.   0.02 0.82 0.16]
# Surfer Dude [0.   0.02 0.82 0.16]
# Surfer Dude [0.   0.02 0.82 0.16]
# Surfer Dude [0.   0.02 0.8  0.18]
# Surfer Dude [0.   0.02 0.8  0.18]
# Surfer Dude [0.   0.03 0.74 0.23]
# Surfer Dude [0.   0.03 0.74 0.23]
# Surfer Dude [0.   0.03 0.64 0.33]
# Surfer Dude [0.   0.03 0.63 0.34]
# Surfer Dude [0.   0.03 0.61 0.36]
# Surfer Dude [0.   0.05 0.56 0.39]
# Surfer Dude [0.   0.05 0.59 0.36]
# Surfer Dude [0.   0.04 0.76 0.2 ]
# Surfer Dude [0.   0.03 0.72 0.25]
# Surfer Dude [0.   0.02 0.86 0.12]
# Surfer Dude [0.   0.01 0.9  0.09]
# Surfer Dude [0.   0.01 0.92 0.07]
# Surfer Dude [0.   0.01 0.93 0.06]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.92 0.07]
# Surfer Dude [0.   0.01 0.92 0.07]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.   0.   0.94 0.06]
# Sad [0.19 0.34 0.27 0.2 ]
# Wakanda Forever [0.02 0.08 0.37 0.53]
# Wakanda Forever [0.01 0.1  0.39 0.5 ]
# Wakanda Forever [0.   0.08 0.4  0.52]
# Wakanda Forever [0.   0.06 0.41 0.53]
# Wakanda Forever [0.   0.1  0.43 0.47]
# Happy [0.46 0.17 0.2  0.17]
# Wakanda Forever [0.18 0.19 0.07 0.56]
# Wakanda Forever [0.03 0.22 0.05 0.7 ]
# Wakanda Forever [0.01 0.24 0.08 0.67]
# Wakanda Forever [0.03 0.22 0.08 0.67]
# Wakanda Forever [0.03 0.24 0.07 0.66]
# Wakanda Forever [0.03 0.28 0.07 0.62]
# Wakanda Forever [0.01 0.32 0.08 0.59]
# Wakanda Forever [0.01 0.33 0.07 0.59]
# Wakanda Forever [0.   0.37 0.07 0.56]
# Wakanda Forever [0.01 0.35 0.04 0.6 ]
# Wakanda Forever [0.01 0.35 0.05 0.59]
# Wakanda Forever [0.02 0.26 0.06 0.66]
# Surfer Dude [0.   0.06 0.75 0.19]
# Surfer Dude [0.02 0.03 0.82 0.13]
# Surfer Dude [0.   0.   0.84 0.16]
# Surfer Dude [0.   0.02 0.88 0.1 ]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.05 0.76 0.19]
# Surfer Dude [0.   0.11 0.61 0.28]
# Wakanda Forever [0.   0.04 0.44 0.52]
# Wakanda Forever [0.  0.1 0.4 0.5]
# Wakanda Forever [0.   0.32 0.33 0.35]
# Wakanda Forever [0.   0.11 0.34 0.55]
# Wakanda Forever [0.   0.19 0.31 0.5 ]
# Wakanda Forever [0.  0.2 0.3 0.5]
# Wakanda Forever [0.   0.22 0.28 0.5 ]
# Wakanda Forever [0.01 0.25 0.28 0.46]
# Wakanda Forever [0.02 0.23 0.22 0.53]
# Wakanda Forever [0.01 0.27 0.22 0.5 ]
# Wakanda Forever [0.01 0.25 0.23 0.51]
# Wakanda Forever [0.01 0.26 0.19 0.54]
# Wakanda Forever [0.01 0.28 0.15 0.56]
# Wakanda Forever [0.01 0.36 0.12 0.51]
# Wakanda Forever [0.01 0.37 0.12 0.5 ]
# Wakanda Forever [0.01 0.38 0.11 0.5 ]
# Wakanda Forever [0.01 0.38 0.09 0.52]
# Wakanda Forever [0.01 0.37 0.07 0.55]
# Wakanda Forever [0.01 0.36 0.07 0.56]
# Wakanda Forever [0.01 0.41 0.07 0.51]
# Wakanda Forever [0.01 0.43 0.08 0.48]
# Wakanda Forever [0.01 0.38 0.08 0.53]
# Wakanda Forever [0.04 0.44 0.07 0.45]
# Wakanda Forever [0.04 0.44 0.07 0.45]
# Wakanda Forever [0.04 0.43 0.08 0.45]
# Sad [0.03 0.45 0.07 0.45]
# Wakanda Forever [0.03 0.43 0.08 0.46]
# Wakanda Forever [0.03 0.42 0.09 0.46]
# Sad [0.03 0.47 0.07 0.43]
# Sad [0.04 0.47 0.07 0.42]
# Sad [0.05 0.52 0.07 0.36]
# Sad [0.06 0.51 0.11 0.32]
# Sad [0.07 0.56 0.11 0.26]
# Wakanda Forever [0.07 0.36 0.09 0.48]
# Sad [0.05 0.55 0.11 0.29]
# Sad [0.11 0.49 0.1  0.3 ]
# Wakanda Forever [0.1  0.38 0.09 0.43]
# Sad [0.3  0.49 0.09 0.12]
# Sad [0.33 0.5  0.05 0.12]
# Sad [0.31 0.54 0.04 0.11]
# Sad [0.23 0.6  0.06 0.11]
# Sad [0.24 0.6  0.06 0.1 ]
# Sad [0.18 0.65 0.06 0.11]
# Sad [0.11 0.63 0.05 0.21]
# Sad [0.07 0.69 0.04 0.2 ]
# Sad [0.09 0.73 0.04 0.14]
# Sad [0.09 0.66 0.05 0.2 ]
# Sad [0.01 0.56 0.03 0.4 ]
# Sad [0.   0.53 0.05 0.42]
# Sad [0.02 0.48 0.05 0.45]
# Sad [0.03 0.49 0.04 0.44]
# Sad [0.03 0.52 0.04 0.41]
# Sad [0.03 0.51 0.04 0.42]
# Sad [0.03 0.54 0.03 0.4 ]
# Sad [0.04 0.54 0.04 0.38]
# Sad [0.05 0.52 0.02 0.41]
# Sad [0.05 0.51 0.03 0.41]
# Sad [0.06 0.48 0.05 0.41]
# Sad [0.08 0.48 0.05 0.39]
# Sad [0.07 0.45 0.05 0.43]
# Wakanda Forever [0.1  0.4  0.05 0.45]
# Wakanda Forever [0.1  0.4  0.05 0.45]
# Wakanda Forever [0.09 0.37 0.06 0.48]
# Wakanda Forever [0.08 0.35 0.05 0.52]
# Wakanda Forever [0.09 0.36 0.05 0.5 ]
# Wakanda Forever [0.09 0.35 0.06 0.5 ]
# Wakanda Forever [0.11 0.36 0.06 0.47]
# Sad [0.02 0.54 0.07 0.37]
# Sad [0.02 0.55 0.07 0.36]
# Sad [0.04 0.54 0.08 0.34]
# Sad [0.04 0.49 0.11 0.36]
# Wakanda Forever [0.05 0.35 0.1  0.5 ]
# Wakanda Forever [0.07 0.36 0.08 0.49]
# Wakanda Forever [0.07 0.36 0.09 0.48]
# Wakanda Forever [0.07 0.29 0.1  0.54]
# Wakanda Forever [0.09 0.28 0.1  0.53]
# Wakanda Forever [0.13 0.32 0.05 0.5 ]
# Wakanda Forever [0.15 0.24 0.03 0.58]
# Wakanda Forever [0.13 0.27 0.09 0.51]
# Wakanda Forever [0.11 0.31 0.09 0.49]
# Wakanda Forever [0.11 0.3  0.11 0.48]
# Wakanda Forever [0.11 0.31 0.11 0.47]
# Wakanda Forever [0.13 0.31 0.1  0.46]
# Wakanda Forever [0.14 0.28 0.1  0.48]
# Wakanda Forever [0.16 0.32 0.07 0.45]
# Sad [0.11 0.44 0.06 0.39]
# Wakanda Forever [0.07 0.4  0.08 0.45]
# Sad [0.07 0.44 0.06 0.43]
# Wakanda Forever [0.02 0.4  0.08 0.5 ]
# Wakanda Forever [0.06 0.28 0.11 0.55]
# Wakanda Forever [0.06 0.17 0.14 0.63]
# Wakanda Forever [0.05 0.32 0.12 0.51]
# Wakanda Forever [0.07 0.28 0.07 0.58]
# Wakanda Forever [0.09 0.27 0.06 0.58]
# Wakanda Forever [0.07 0.38 0.04 0.51]
# Wakanda Forever [0.06 0.44 0.03 0.47]
# Sad [0.12 0.5  0.03 0.35]
# Sad [0.09 0.63 0.04 0.24]
# Sad [0.12 0.61 0.02 0.25]
# Sad [0.05 0.59 0.03 0.33]
# Wakanda Forever [0.02 0.26 0.09 0.63]
# Wakanda Forever [0.04 0.19 0.1  0.67]
# Wakanda Forever [0.05 0.41 0.07 0.47]
# Sad [0.05 0.57 0.05 0.33]
# Sad [0.04 0.52 0.07 0.37]
# Sad [0.04 0.5  0.07 0.39]
# Wakanda Forever [0.05 0.4  0.06 0.49]
# Wakanda Forever [0.05 0.2  0.08 0.67]
# Wakanda Forever [0.   0.15 0.08 0.77]
# Wakanda Forever [0.   0.18 0.07 0.75]
# Happy [0.37 0.27 0.17 0.19]
# Happy [0.55 0.24 0.12 0.09]
# Sad [0.31 0.42 0.03 0.24]
# Wakanda Forever [0.19 0.28 0.05 0.48]
# Wakanda Forever [0.18 0.27 0.04 0.51]
# Wakanda Forever [0.16 0.31 0.05 0.48]
# Wakanda Forever [0.14 0.34 0.05 0.47]
# Wakanda Forever [0.13 0.32 0.06 0.49]
# Wakanda Forever [0.13 0.3  0.04 0.53]
# Wakanda Forever [0.14 0.32 0.03 0.51]
# Wakanda Forever [0.12 0.33 0.03 0.52]
# Wakanda Forever [0.09 0.34 0.04 0.53]
# Wakanda Forever [0.07 0.35 0.05 0.53]
# Wakanda Forever [0.07 0.34 0.05 0.54]
# Wakanda Forever [0.07 0.33 0.06 0.54]
# Wakanda Forever [0.09 0.29 0.06 0.56]
# Wakanda Forever [0.15 0.27 0.05 0.53]
# Wakanda Forever [0.17 0.28 0.04 0.51]
# Wakanda Forever [0.18 0.26 0.04 0.52]
# Wakanda Forever [0.18 0.29 0.04 0.49]
# Wakanda Forever [0.18 0.27 0.04 0.51]
# Wakanda Forever [0.18 0.3  0.04 0.48]
# Wakanda Forever [0.17 0.3  0.04 0.49]
# Wakanda Forever [0.16 0.31 0.04 0.49]
# Wakanda Forever [0.18 0.31 0.04 0.47]
# Wakanda Forever [0.17 0.36 0.04 0.43]
# Wakanda Forever [0.03 0.11 0.39 0.47]
# Wakanda Forever [0.01 0.12 0.36 0.51]
# Happy [0.47 0.18 0.21 0.14]
# Happy [0.47 0.12 0.21 0.2 ]
# Happy [0.32 0.19 0.23 0.26]
# Sad [0.12 0.34 0.27 0.27]
# Sad [0.08 0.41 0.26 0.25]
# Surfer Dude [0.21 0.25 0.32 0.22]
# Surfer Dude [0.25 0.23 0.34 0.18]
# Surfer Dude [0.28 0.21 0.32 0.19]
# Surfer Dude [0.25 0.25 0.34 0.16]
# Surfer Dude [0.26 0.24 0.33 0.17]
# Surfer Dude [0.23 0.21 0.35 0.21]
# Wakanda Forever [0.22 0.15 0.31 0.32]
# Wakanda Forever [0.23 0.18 0.25 0.34]
# Wakanda Forever [0.18 0.24 0.26 0.32]
# Sad [0.17 0.32 0.23 0.28]
# Wakanda Forever [0.26 0.22 0.24 0.28]
# Happy [0.27 0.26 0.23 0.24]
# Wakanda Forever [0.26 0.22 0.22 0.3 ]
# Wakanda Forever [0.27 0.26 0.19 0.28]
# Wakanda Forever [0.28 0.26 0.16 0.3 ]
# Happy [0.29 0.28 0.15 0.28]
# Sad [0.27 0.3  0.18 0.25]
# Happy [0.31 0.26 0.13 0.3 ]
# Sad [0.33 0.39 0.09 0.19]
# Happy [0.44 0.33 0.06 0.17]
# Happy [0.39 0.31 0.1  0.2 ]
# Happy [0.37 0.34 0.14 0.15]
# Sad [0.32 0.36 0.13 0.19]
# Sad [0.3  0.37 0.14 0.19]
# Sad [0.28 0.37 0.17 0.18]
# Happy [0.39 0.34 0.09 0.18]
# Wakanda Forever [0.02 0.25 0.07 0.66]
# Wakanda Forever [0.05 0.27 0.02 0.66]
# Sad [0.18 0.46 0.04 0.32]
# Wakanda Forever [0.04 0.42 0.07 0.47]
# Sad [0.11 0.52 0.11 0.26]
# Sad [0.25 0.43 0.15 0.17]
# Sad [0.34 0.36 0.17 0.13]
# Sad [0.34 0.4  0.15 0.11]
# Sad [0.36 0.39 0.13 0.12]
# Sad [0.37 0.38 0.12 0.13]
# Happy [0.38 0.37 0.12 0.13]
# Happy [0.38 0.35 0.13 0.14]
# Sad [0.34 0.39 0.16 0.11]
# Sad [0.31 0.42 0.13 0.14]
# Happy [0.4  0.35 0.13 0.12]
# Happy [0.39 0.3  0.16 0.15]
# Sad [0.26 0.32 0.19 0.23]
# Happy [0.34 0.25 0.18 0.23]
# Happy [0.34 0.23 0.18 0.25]
# Sad [0.21 0.37 0.11 0.31]
# Sad [0.23 0.35 0.12 0.3 ]
# Sad [0.21 0.36 0.11 0.32]
# Wakanda Forever [0.2  0.34 0.11 0.35]
# Sad [0.22 0.34 0.11 0.33]
# Sad [0.22 0.34 0.14 0.3 ]
# Happy [0.35 0.24 0.15 0.26]
# Happy [0.36 0.23 0.15 0.26]
# Happy [0.36 0.2  0.16 0.28]
# Happy [0.37 0.19 0.16 0.28]
# Happy [0.34 0.22 0.15 0.29]
# Happy [0.36 0.2  0.16 0.28]
# Wakanda Forever [0.27 0.27 0.15 0.31]
# Happy [0.31 0.27 0.14 0.28]
# Happy [0.36 0.24 0.15 0.25]
# Happy [0.33 0.26 0.19 0.22]
# Happy [0.34 0.25 0.21 0.2 ]
# Happy [0.33 0.27 0.21 0.19]
# Happy [0.33 0.26 0.21 0.2 ]
# Happy [0.33 0.26 0.22 0.19]
# Happy [0.32 0.27 0.23 0.18]
# Sad [0.28 0.29 0.25 0.18]
# Sad [0.3  0.31 0.21 0.18]
# Happy [0.29 0.29 0.23 0.19]
# Sad [0.3  0.31 0.23 0.16]
# Happy [0.31 0.29 0.23 0.17]
# Happy [0.31 0.3  0.22 0.17]
# Sad [0.3  0.31 0.23 0.16]
# Sad [0.29 0.3  0.24 0.17]
# Happy [0.3  0.3  0.23 0.17]
# Happy [0.31 0.28 0.22 0.19]
# Happy [0.3  0.28 0.23 0.19]
# Happy [0.29 0.28 0.22 0.21]
# Happy [0.31 0.26 0.23 0.2 ]
# Happy [0.32 0.23 0.21 0.24]
# Happy [0.31 0.24 0.21 0.24]
# Happy [0.33 0.23 0.19 0.25]
# Happy [0.33 0.22 0.19 0.26]
# Happy [0.3  0.24 0.21 0.25]
# Happy [0.31 0.23 0.2  0.26]
# Happy [0.3  0.23 0.22 0.25]
# Happy [0.31 0.21 0.21 0.27]
# Happy [0.3  0.22 0.2  0.28]
# Happy [0.32 0.22 0.18 0.28]
# Happy [0.32 0.2  0.19 0.29]
# Happy [0.32 0.22 0.18 0.28]
# Happy [0.31 0.22 0.19 0.28]
# Wakanda Forever [0.23 0.26 0.2  0.31]
# Wakanda Forever [0.21 0.3  0.15 0.34]
# Wakanda Forever [0.19 0.3  0.19 0.32]
# Happy [0.31 0.21 0.19 0.29]
# Happy [0.34 0.22 0.19 0.25]
# Happy [0.35 0.23 0.18 0.24]
# Happy [0.34 0.23 0.22 0.21]
# Happy [0.34 0.23 0.2  0.23]
# Happy [0.34 0.24 0.21 0.21]
# Happy [0.34 0.24 0.21 0.21]
# Happy [0.34 0.24 0.19 0.23]
# Happy [0.34 0.24 0.2  0.22]
# Happy [0.34 0.24 0.2  0.22]
# Happy [0.35 0.23 0.21 0.21]
# Happy [0.35 0.23 0.21 0.21]
# Happy [0.35 0.23 0.21 0.21]
# Happy [0.35 0.23 0.21 0.21]
# Happy [0.35 0.23 0.2  0.22]
# Happy [0.35 0.22 0.21 0.22]
# Happy [0.34 0.23 0.21 0.22]
# Happy [0.35 0.23 0.2  0.22]
# Happy [0.32 0.26 0.18 0.24]
# Happy [0.31 0.25 0.21 0.23]
# Wakanda Forever [0.24 0.29 0.16 0.31]
# Wakanda Forever [0.21 0.31 0.13 0.35]
# Wakanda Forever [0.19 0.3  0.14 0.37]
# Wakanda Forever [0.19 0.3  0.13 0.38]
# Wakanda Forever [0.23 0.26 0.19 0.32]
# Happy [0.28 0.25 0.2  0.27]
# Happy [0.29 0.24 0.2  0.27]
# Happy [0.29 0.26 0.2  0.25]
# Happy [0.29 0.26 0.22 0.23]
# Happy [0.3  0.24 0.21 0.25]
# Happy [0.29 0.25 0.21 0.25]
# Happy [0.29 0.24 0.21 0.26]
# Happy [0.3  0.23 0.22 0.25]
# Happy [0.3  0.26 0.21 0.23]
# Happy [0.3  0.26 0.22 0.22]
# Happy [0.3  0.26 0.22 0.22]
# Happy [0.3  0.25 0.22 0.23]
# Happy [0.3  0.25 0.22 0.23]
# Happy [0.3  0.25 0.23 0.22]
# Happy [0.3  0.25 0.23 0.22]
# Happy [0.29 0.23 0.21 0.27]
# Happy [0.29 0.24 0.24 0.23]
# Happy [0.3  0.25 0.23 0.22]
# Happy [0.3  0.23 0.24 0.23]
# Happy [0.29 0.23 0.24 0.24]
# Happy [0.27 0.23 0.25 0.25]
# Wakanda Forever [0.25 0.24 0.25 0.26]
# Wakanda Forever [0.24 0.24 0.25 0.27]
# Happy [0.26 0.24 0.26 0.24]
# Happy [0.26 0.25 0.25 0.24]
# Happy [0.27 0.25 0.24 0.24]
# Happy [0.26 0.25 0.24 0.25]
# Happy [0.29 0.23 0.22 0.26]
# Sad [0.24 0.27 0.22 0.27]
# Happy [0.28 0.25 0.23 0.24]
# Happy [0.29 0.25 0.23 0.23]
# Happy [0.27 0.26 0.24 0.23]
# Sad [0.26 0.27 0.25 0.22]
# Sad [0.26 0.27 0.24 0.23]
# Happy [0.27 0.27 0.23 0.23]
# Sad [0.26 0.27 0.24 0.23]
# Happy [0.27 0.27 0.24 0.22]
# Sad [0.26 0.27 0.25 0.22]
# Sad [0.26 0.27 0.24 0.23]
# Sad [0.26 0.27 0.24 0.23]
# Happy [0.28 0.26 0.23 0.23]
# Happy [0.28 0.25 0.24 0.23]
# Happy [0.29 0.24 0.23 0.24]
# Happy [0.3  0.24 0.22 0.24]
# Happy [0.29 0.25 0.23 0.23]
# Happy [0.29 0.26 0.23 0.22]
# Happy [0.3  0.24 0.25 0.21]
# Happy [0.31 0.23 0.25 0.21]
# Happy [0.3  0.25 0.25 0.2 ]
# Happy [0.31 0.25 0.23 0.21]
# Happy [0.31 0.25 0.24 0.2 ]
# Happy [0.3  0.25 0.25 0.2 ]
# Happy [0.3  0.25 0.26 0.19]
# Happy [0.31 0.23 0.26 0.2 ]
# Happy [0.29 0.25 0.29 0.17]
# Happy [0.29 0.25 0.29 0.17]
# Happy [0.29 0.25 0.29 0.17]
# Happy [0.3  0.24 0.29 0.17]
# Happy [0.3  0.23 0.28 0.19]
# Happy [0.32 0.23 0.26 0.19]
# Happy [0.32 0.24 0.25 0.19]
# Happy [0.32 0.24 0.25 0.19]
# Happy [0.31 0.23 0.26 0.2 ]
# Happy [0.3  0.23 0.28 0.19]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.32 0.23 0.24 0.21]
# Happy [0.32 0.22 0.26 0.2 ]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.3  0.22 0.29 0.19]
# Happy [0.32 0.22 0.24 0.22]
# Happy [0.32 0.22 0.24 0.22]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.31 0.22 0.25 0.22]
# Happy [0.31 0.22 0.25 0.22]
# Happy [0.31 0.22 0.27 0.2 ]
# Happy [0.32 0.22 0.24 0.22]
# Happy [0.32 0.22 0.24 0.22]
# Happy [0.31 0.22 0.25 0.22]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.31 0.22 0.27 0.2 ]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.33 0.22 0.24 0.21]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.31 0.22 0.27 0.2 ]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.31 0.22 0.27 0.2 ]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.31 0.22 0.27 0.2 ]
# Happy [0.31 0.22 0.27 0.2 ]
# Happy [0.31 0.22 0.27 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.3  0.22 0.27 0.21]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.32 0.22 0.25 0.21]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.22 0.27 0.21]
# Happy [0.31 0.22 0.26 0.21]
# Happy [0.3  0.22 0.27 0.21]
# Happy [0.3  0.22 0.28 0.2 ]
# Happy [0.3  0.23 0.28 0.19]
# Happy [0.31 0.27 0.25 0.17]
# Happy [0.33 0.3  0.2  0.17]
# Happy [0.35 0.35 0.18 0.12]
# Happy [0.37 0.33 0.18 0.12]
# Happy [0.36 0.35 0.18 0.11]
# Happy [0.36 0.33 0.2  0.11]
# Happy [0.37 0.34 0.18 0.11]
# Happy [0.37 0.34 0.17 0.12]
# Sad [0.34 0.35 0.19 0.12]
# Happy [0.37 0.33 0.19 0.11]
# Happy [0.37 0.33 0.19 0.11]
# Happy [0.36 0.32 0.22 0.1 ]
# Happy [0.36 0.33 0.21 0.1 ]
# Happy [0.37 0.33 0.2  0.1 ]
# Happy [0.37 0.33 0.2  0.1 ]
# Happy [0.37 0.33 0.2  0.1 ]
# Happy [0.37 0.33 0.2  0.1 ]
# Happy [0.35 0.33 0.22 0.1 ]
# Happy [0.36 0.33 0.21 0.1 ]
# Happy [0.37 0.34 0.19 0.1 ]
# Happy [0.37 0.34 0.19 0.1 ]
# Happy [0.37 0.35 0.19 0.09]
# Happy [0.36 0.35 0.19 0.1 ]
# Happy [0.36 0.34 0.2  0.1 ]
# Happy [0.36 0.35 0.19 0.1 ]
# Happy [0.35 0.35 0.2  0.1 ]
# Happy [0.36 0.34 0.21 0.09]
# Happy [0.36 0.34 0.2  0.1 ]
# Happy [0.36 0.32 0.21 0.11]
# Happy [0.34 0.33 0.23 0.1 ]
# Happy [0.34 0.33 0.23 0.1 ]
# Happy [0.34 0.32 0.23 0.11]
# Sad [0.31 0.35 0.22 0.12]
# Happy [0.32 0.32 0.22 0.14]
# Happy [0.32 0.28 0.2  0.2 ]
# Happy [0.31 0.29 0.21 0.19]
# Sad [0.3  0.31 0.21 0.18]
# Sad [0.3  0.31 0.2  0.19]
# Sad [0.27 0.35 0.22 0.16]
# Sad [0.29 0.3  0.22 0.19]
# Sad [0.24 0.35 0.23 0.18]
# Sad [0.28 0.4  0.19 0.13]
# Sad [0.18 0.51 0.18 0.13]
# Sad [0.18 0.47 0.2  0.15]
# Sad [0.14 0.48 0.21 0.17]
# Sad [0.13 0.52 0.18 0.17]
# Sad [0.13 0.36 0.22 0.29]
# Wakanda Forever [0.22 0.28 0.2  0.3 ]
# Surfer Dude [0.26 0.25 0.28 0.21]
# Happy [0.43 0.21 0.23 0.13]
# Happy [0.44 0.24 0.18 0.14]
# Happy [0.47 0.21 0.21 0.11]
# Happy [0.32 0.29 0.1  0.29]
# Sad [0.25 0.34 0.1  0.31]
# Sad [0.23 0.37 0.1  0.3 ]
# Sad [0.2  0.37 0.1  0.33]
# Sad [0.08 0.53 0.12 0.27]
# Wakanda Forever [0.01 0.43 0.06 0.5 ]
# Wakanda Forever [0.01 0.42 0.07 0.5 ]
# Surfer Dude [0.   0.03 0.9  0.07]
# Surfer Dude [0.   0.02 0.91 0.07]
# Surfer Dude [0.   0.02 0.9  0.08]
# Surfer Dude [0.   0.02 0.92 0.06]
# Surfer Dude [0.   0.02 0.92 0.06]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.92 0.07]
# Surfer Dude [0.   0.03 0.88 0.09]
# Surfer Dude [0.   0.03 0.88 0.09]
# Surfer Dude [0.   0.03 0.84 0.13]
# Surfer Dude [0.   0.03 0.9  0.07]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.9  0.09]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.01 0.9  0.09]
# Surfer Dude [0.   0.01 0.9  0.09]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.   0.89 0.11]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.85 0.15]
# Surfer Dude [0.  0.  0.8 0.2]
# Surfer Dude [0.   0.   0.81 0.19]
# Surfer Dude [0.   0.   0.82 0.18]
# Surfer Dude [0.   0.   0.82 0.18]
# Surfer Dude [0.   0.03 0.83 0.14]
# Surfer Dude [0.   0.02 0.86 0.12]
# Surfer Dude [0.   0.04 0.85 0.11]
# Surfer Dude [0.   0.09 0.79 0.12]
# Surfer Dude [0.32 0.14 0.42 0.12]
# Surfer Dude [0.33 0.13 0.42 0.12]
# Surfer Dude [0.36 0.09 0.4  0.15]
# Surfer Dude [0.36 0.09 0.4  0.15]
# Surfer Dude [0.36 0.1  0.4  0.14]
# Happy [0.38 0.11 0.34 0.17]
# Happy [0.37 0.1  0.36 0.17]
# Happy [0.39 0.11 0.34 0.16]
# Happy [0.39 0.11 0.24 0.26]
# Happy [0.37 0.12 0.27 0.24]
# Happy [0.44 0.11 0.23 0.22]
# Happy [0.41 0.12 0.25 0.22]
# Happy [0.42 0.12 0.25 0.21]
# Happy [0.44 0.11 0.24 0.21]
# Happy [0.37 0.18 0.22 0.23]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.94 0.06]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.01 0.86 0.13]
# Surfer Dude [0.   0.03 0.84 0.13]
# Surfer Dude [0.21 0.21 0.33 0.25]
# Surfer Dude [0.17 0.16 0.48 0.19]
# Surfer Dude [0.18 0.16 0.48 0.18]
# Surfer Dude [0.19 0.16 0.47 0.18]
# Surfer Dude [0.   0.   0.84 0.16]
# Surfer Dude [0.   0.01 0.86 0.13]
# Surfer Dude [0.01 0.04 0.81 0.14]
# Surfer Dude [0.08 0.05 0.74 0.13]
# Wakanda Forever [0.01 0.06 0.46 0.47]
# Wakanda Forever [0.01 0.07 0.45 0.47]
# Surfer Dude [0.01 0.08 0.46 0.45]
# Surfer Dude [0.01 0.08 0.46 0.45]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.01 0.03 0.86 0.1 ]
# Surfer Dude [0.   0.02 0.88 0.1 ]
# Surfer Dude [0.   0.02 0.89 0.09]
# Surfer Dude [0.   0.02 0.9  0.08]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.   0.87 0.13]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.   0.85 0.15]
# Surfer Dude [0.   0.01 0.84 0.15]
# Surfer Dude [0.   0.01 0.83 0.16]
# Surfer Dude [0.   0.01 0.84 0.15]
# Surfer Dude [0.   0.01 0.84 0.15]
# Surfer Dude [0.   0.01 0.83 0.16]
# Surfer Dude [0.   0.01 0.84 0.15]
# Surfer Dude [0.   0.01 0.84 0.15]
# Surfer Dude [0.   0.01 0.83 0.16]
# Surfer Dude [0.   0.01 0.83 0.16]
# Surfer Dude [0.   0.02 0.87 0.11]
# Surfer Dude [0.   0.03 0.83 0.14]
# Surfer Dude [0.01 0.02 0.83 0.14]
# Surfer Dude [0.01 0.04 0.82 0.13]
# Surfer Dude [0.01 0.04 0.82 0.13]
# Surfer Dude [0.01 0.04 0.82 0.13]
# Surfer Dude [0.   0.05 0.82 0.13]
# Surfer Dude [0.   0.04 0.82 0.14]
# Surfer Dude [0.01 0.03 0.82 0.14]
# Surfer Dude [0.01 0.03 0.83 0.13]
# Surfer Dude [0.01 0.03 0.83 0.13]
# Surfer Dude [0.01 0.02 0.83 0.14]
# Surfer Dude [0.01 0.03 0.8  0.16]
# Surfer Dude [0.01 0.03 0.82 0.14]
# Surfer Dude [0.   0.05 0.82 0.13]
# Surfer Dude [0.   0.05 0.83 0.12]
# Surfer Dude [0.   0.05 0.79 0.16]
# Surfer Dude [0.   0.05 0.79 0.16]
# Surfer Dude [0.   0.05 0.78 0.17]
# Surfer Dude [0.   0.05 0.78 0.17]
# Surfer Dude [0.   0.05 0.81 0.14]
# Surfer Dude [0.01 0.04 0.85 0.1 ]
# Surfer Dude [0.01 0.04 0.84 0.11]
# Surfer Dude [0.01 0.04 0.84 0.11]
# Surfer Dude [0.01 0.04 0.84 0.11]
# Surfer Dude [0.01 0.03 0.84 0.12]
# Surfer Dude [0.01 0.03 0.84 0.12]
# Surfer Dude [0.01 0.03 0.87 0.09]
# Surfer Dude [0.01 0.03 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.85 0.11]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.84 0.12]
# Surfer Dude [0.01 0.03 0.85 0.11]
# Surfer Dude [0.01 0.04 0.83 0.12]
# Surfer Dude [0.   0.06 0.83 0.11]
# Surfer Dude [0.01 0.04 0.83 0.12]
# Surfer Dude [0.01 0.05 0.82 0.12]
# Surfer Dude [0.   0.06 0.82 0.12]
# Surfer Dude [0.   0.06 0.82 0.12]
# Surfer Dude [0.   0.05 0.82 0.13]
# Surfer Dude [0.   0.06 0.83 0.11]
# Surfer Dude [0.   0.06 0.83 0.11]
# Surfer Dude [0.   0.06 0.83 0.11]
# Surfer Dude [0.   0.06 0.83 0.11]
# Surfer Dude [0.01 0.05 0.83 0.11]
# Surfer Dude [0.01 0.06 0.74 0.19]
# Surfer Dude [0.02 0.06 0.72 0.2 ]
# Surfer Dude [0.03 0.06 0.67 0.24]
# Surfer Dude [0.03 0.06 0.67 0.24]
# Surfer Dude [0.02 0.07 0.67 0.24]
# Surfer Dude [0.03 0.08 0.61 0.28]
# Surfer Dude [0.01 0.09 0.61 0.29]
# Surfer Dude [0.02 0.09 0.59 0.3 ]
# Surfer Dude [0.03 0.08 0.66 0.23]
# Surfer Dude [0.02 0.09 0.68 0.21]
# Surfer Dude [0.05 0.1  0.57 0.28]
# Surfer Dude [0.04 0.11 0.58 0.27]
# Surfer Dude [0.03 0.08 0.56 0.33]
# Surfer Dude [0.03 0.08 0.55 0.34]
# Surfer Dude [0.02 0.08 0.62 0.28]
# Surfer Dude [0.   0.05 0.8  0.15]
# Surfer Dude [0.   0.05 0.81 0.14]
# Surfer Dude [0.   0.06 0.8  0.14]
# Surfer Dude [0.   0.05 0.81 0.14]
# Surfer Dude [0.   0.04 0.82 0.14]
# Surfer Dude [0.   0.04 0.82 0.14]
# Surfer Dude [0.   0.04 0.84 0.12]
# Surfer Dude [0.   0.04 0.84 0.12]
# Surfer Dude [0.   0.04 0.84 0.12]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.05 0.83 0.12]
# Surfer Dude [0.   0.06 0.82 0.12]
# Surfer Dude [0.   0.06 0.82 0.12]
# Surfer Dude [0.   0.05 0.81 0.14]
# Surfer Dude [0.   0.05 0.81 0.14]
# Surfer Dude [0.   0.05 0.77 0.18]
# Surfer Dude [0.   0.07 0.73 0.2 ]
# Surfer Dude [0.   0.09 0.66 0.25]
# Surfer Dude [0.   0.09 0.63 0.28]
# Surfer Dude [0.   0.07 0.64 0.29]
# Surfer Dude [0.   0.08 0.61 0.31]
# Surfer Dude [0.   0.08 0.59 0.33]
# Surfer Dude [0.   0.08 0.57 0.35]
# Surfer Dude [0.   0.1  0.54 0.36]
# Surfer Dude [0.   0.1  0.54 0.36]
# Surfer Dude [0.   0.08 0.56 0.36]
# Surfer Dude [0.   0.06 0.6  0.34]
# Surfer Dude [0.   0.02 0.59 0.39]
# Surfer Dude [0.01 0.02 0.59 0.38]
# Surfer Dude [0.01 0.03 0.6  0.36]
# Surfer Dude [0.   0.03 0.62 0.35]
# Surfer Dude [0.   0.03 0.64 0.33]
# Surfer Dude [0.   0.03 0.64 0.33]
# Surfer Dude [0.   0.02 0.67 0.31]
# Surfer Dude [0.   0.03 0.7  0.27]
# Surfer Dude [0.   0.03 0.7  0.27]
# Surfer Dude [0.   0.01 0.7  0.29]
# Surfer Dude [0.   0.01 0.7  0.29]
# Surfer Dude [0.   0.01 0.68 0.31]
# Surfer Dude [0.   0.01 0.68 0.31]
# Surfer Dude [0.   0.01 0.67 0.32]
# Surfer Dude [0.   0.01 0.67 0.32]
# Surfer Dude [0.03 0.03 0.7  0.24]
# Surfer Dude [0.03 0.03 0.64 0.3 ]
# Surfer Dude [0.03 0.03 0.6  0.34]
# Surfer Dude [0.03 0.04 0.61 0.32]
# Surfer Dude [0.03 0.04 0.61 0.32]
# Surfer Dude [0.03 0.04 0.59 0.34]
# Surfer Dude [0.03 0.05 0.57 0.35]
# Surfer Dude [0.03 0.03 0.56 0.38]
# Surfer Dude [0.03 0.03 0.56 0.38]
# Surfer Dude [0.03 0.03 0.56 0.38]
# Surfer Dude [0.03 0.03 0.58 0.36]
# Surfer Dude [0.03 0.03 0.58 0.36]
# Surfer Dude [0.03 0.03 0.56 0.38]
# Surfer Dude [0.03 0.03 0.57 0.37]
# Surfer Dude [0.03 0.03 0.57 0.37]
# Surfer Dude [0.03 0.03 0.57 0.37]
# Surfer Dude [0.03 0.03 0.58 0.36]
# Surfer Dude [0.03 0.03 0.6  0.34]
# Surfer Dude [0.03 0.03 0.59 0.35]
# Surfer Dude [0.03 0.03 0.61 0.33]
# Surfer Dude [0.03 0.03 0.61 0.33]
# Surfer Dude [0.03 0.03 0.62 0.32]
# Surfer Dude [0.03 0.03 0.63 0.31]
# Surfer Dude [0.03 0.03 0.63 0.31]
# Surfer Dude [0.03 0.03 0.63 0.31]
# Surfer Dude [0.03 0.03 0.61 0.33]
# Surfer Dude [0.03 0.03 0.6  0.34]
# Surfer Dude [0.03 0.03 0.59 0.35]
# Surfer Dude [0.03 0.03 0.6  0.34]
# Surfer Dude [0.03 0.03 0.6  0.34]
# Surfer Dude [0.03 0.03 0.6  0.34]
# Surfer Dude [0.03 0.03 0.62 0.32]
# Surfer Dude [0.03 0.05 0.62 0.3 ]
# Surfer Dude [0.03 0.05 0.61 0.31]
# Surfer Dude [0.03 0.05 0.61 0.31]
# Surfer Dude [0.03 0.05 0.61 0.31]
# Surfer Dude [0.03 0.05 0.61 0.31]
# Surfer Dude [0.03 0.05 0.62 0.3 ]
# Surfer Dude [0.03 0.05 0.61 0.31]
# Surfer Dude [0.03 0.05 0.62 0.3 ]
# Surfer Dude [0.03 0.05 0.62 0.3 ]
# Surfer Dude [0.03 0.05 0.63 0.29]
# Surfer Dude [0.03 0.04 0.65 0.28]
# Surfer Dude [0.03 0.04 0.65 0.28]
# Surfer Dude [0.03 0.03 0.67 0.27]
# Surfer Dude [0.03 0.03 0.66 0.28]
# Surfer Dude [0.03 0.03 0.66 0.28]
# Surfer Dude [0.03 0.03 0.66 0.28]
# Surfer Dude [0.03 0.03 0.66 0.28]
# Surfer Dude [0.03 0.03 0.66 0.28]
# Surfer Dude [0.03 0.03 0.66 0.28]
# Surfer Dude [0.02 0.03 0.69 0.26]
# Surfer Dude [0.02 0.02 0.77 0.19]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.88 0.08]
# Surfer Dude [0.   0.02 0.91 0.07]
# Surfer Dude [0.   0.02 0.91 0.07]
# Surfer Dude [0.   0.02 0.87 0.11]
# Surfer Dude [0.   0.02 0.87 0.11]
# Surfer Dude [0.   0.02 0.87 0.11]
# Surfer Dude [0.   0.02 0.86 0.12]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.02 0.85 0.13]
# Surfer Dude [0.   0.02 0.85 0.13]
# Surfer Dude [0.   0.02 0.87 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.85 0.11]
# Surfer Dude [0.   0.02 0.85 0.13]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.89 0.1 ]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.86 0.13]
# Surfer Dude [0.   0.05 0.83 0.12]
# Surfer Dude [0.   0.05 0.83 0.12]
# Surfer Dude [0.   0.05 0.83 0.12]
# Surfer Dude [0.   0.04 0.84 0.12]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.04 0.84 0.12]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.04 0.83 0.13]
# Surfer Dude [0.   0.04 0.83 0.13]
# Surfer Dude [0.   0.05 0.82 0.13]
# Surfer Dude [0.   0.05 0.82 0.13]
# Surfer Dude [0.   0.05 0.83 0.12]
# Surfer Dude [0.   0.05 0.85 0.1 ]
# Surfer Dude [0.   0.05 0.86 0.09]
# Surfer Dude [0.   0.05 0.85 0.1 ]
# Surfer Dude [0.   0.05 0.85 0.1 ]
# Surfer Dude [0.   0.05 0.85 0.1 ]
# Surfer Dude [0.   0.05 0.86 0.09]
# Surfer Dude [0.   0.05 0.85 0.1 ]
# Surfer Dude [0.   0.05 0.85 0.1 ]
# Surfer Dude [0.   0.05 0.86 0.09]
# Surfer Dude [0.   0.05 0.86 0.09]
# Surfer Dude [0.   0.04 0.87 0.09]
# Surfer Dude [0.   0.04 0.87 0.09]
# Surfer Dude [0.   0.05 0.86 0.09]
# Surfer Dude [0.   0.04 0.88 0.08]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.17 0.25 0.49 0.09]
# Surfer Dude [0.17 0.3  0.45 0.08]
# Surfer Dude [0.18 0.29 0.44 0.09]
# Surfer Dude [0.17 0.3  0.43 0.1 ]
# Surfer Dude [0.18 0.3  0.44 0.08]
# Surfer Dude [0.02 0.04 0.74 0.2 ]
# Surfer Dude [0.17 0.27 0.47 0.09]
# Surfer Dude [0.22 0.3  0.36 0.12]
# Surfer Dude [0.01 0.13 0.48 0.38]
# Surfer Dude [0.02 0.09 0.47 0.42]
# Wakanda Forever [0.   0.08 0.44 0.48]
# Surfer Dude [0.   0.03 0.82 0.15]
# Surfer Dude [0.   0.04 0.84 0.12]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.03 0.88 0.09]
# Surfer Dude [0.   0.03 0.88 0.09]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.04 0.84 0.12]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.04 0.85 0.11]
# Surfer Dude [0.   0.04 0.87 0.09]
# Surfer Dude [0.   0.03 0.88 0.09]
# Surfer Dude [0.   0.03 0.88 0.09]
# Surfer Dude [0.   0.03 0.88 0.09]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.04 0.84 0.12]
# Surfer Dude [0.   0.04 0.84 0.12]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.05 0.83 0.12]
# Surfer Dude [0.   0.05 0.83 0.12]
# Surfer Dude [0.   0.05 0.83 0.12]
# Surfer Dude [0.   0.05 0.83 0.12]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.04 0.85 0.11]
# Surfer Dude [0.   0.04 0.85 0.11]
# Surfer Dude [0.   0.04 0.85 0.11]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.85 0.11]
# Surfer Dude [0.3  0.19 0.44 0.07]
# Surfer Dude [0.   0.06 0.8  0.14]
# Surfer Dude [0.   0.05 0.87 0.08]
# Surfer Dude [0.   0.04 0.87 0.09]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.04 0.87 0.09]
# Surfer Dude [0.   0.04 0.87 0.09]
# Surfer Dude [0.   0.04 0.87 0.09]
# Surfer Dude [0.   0.04 0.87 0.09]
# Surfer Dude [0.   0.04 0.87 0.09]
# Surfer Dude [0.   0.05 0.85 0.1 ]
# Surfer Dude [0.   0.05 0.84 0.11]
# Surfer Dude [0.   0.05 0.84 0.11]
# Surfer Dude [0.   0.05 0.8  0.15]
# Surfer Dude [0.   0.05 0.8  0.15]
# Surfer Dude [0.   0.04 0.81 0.15]
# Surfer Dude [0.   0.04 0.81 0.15]
# Surfer Dude [0.   0.04 0.81 0.15]
# Surfer Dude [0.   0.04 0.82 0.14]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.03 0.88 0.09]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.03 0.87 0.1 ]
# Surfer Dude [0.   0.03 0.89 0.08]
# Surfer Dude [0.   0.03 0.88 0.09]
# Surfer Dude [0.01 0.02 0.88 0.09]
# Surfer Dude [0.   0.04 0.9  0.06]
# Surfer Dude [0.   0.04 0.9  0.06]
# Surfer Dude [0.   0.04 0.9  0.06]
# Surfer Dude [0.   0.04 0.9  0.06]
# Surfer Dude [0.   0.03 0.91 0.06]
# Surfer Dude [0.   0.03 0.91 0.06]
# Surfer Dude [0.   0.03 0.9  0.07]
# Surfer Dude [0.   0.03 0.91 0.06]
# Surfer Dude [0.   0.03 0.9  0.07]
# Surfer Dude [0.   0.03 0.89 0.08]
# Surfer Dude [0.   0.03 0.89 0.08]
# Surfer Dude [0.   0.03 0.88 0.09]
# Surfer Dude [0.   0.04 0.86 0.1 ]
# Surfer Dude [0.   0.05 0.87 0.08]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.06 0.8  0.14]
# Surfer Dude [0.   0.05 0.8  0.15]
# Surfer Dude [0.   0.05 0.8  0.15]
# Surfer Dude [0.   0.04 0.8  0.16]
# Surfer Dude [0.   0.05 0.8  0.15]
# Surfer Dude [0.   0.05 0.81 0.14]
# Surfer Dude [0.   0.05 0.81 0.14]
# Surfer Dude [0.   0.05 0.81 0.14]
# Surfer Dude [0.   0.04 0.8  0.16]
# Surfer Dude [0.   0.04 0.8  0.16]
# Surfer Dude [0.   0.02 0.82 0.16]
# Surfer Dude [0.   0.02 0.82 0.16]
# Surfer Dude [0.   0.02 0.84 0.14]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.03 0.85 0.12]
# Surfer Dude [0.   0.02 0.84 0.14]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.   0.87 0.13]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.84 0.15]
# Surfer Dude [0.   0.01 0.84 0.15]
# Surfer Dude [0.   0.02 0.83 0.15]
# Surfer Dude [0.   0.01 0.84 0.15]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.01 0.93 0.06]
# Surfer Dude [0.   0.02 0.93 0.05]
# Surfer Dude [0.   0.03 0.92 0.05]
# Surfer Dude [0.   0.03 0.92 0.05]
# Surfer Dude [0.   0.03 0.91 0.06]
# Surfer Dude [0.   0.03 0.92 0.05]
# Surfer Dude [0.   0.03 0.9  0.07]
# Surfer Dude [0.   0.03 0.9  0.07]
# Surfer Dude [0.   0.03 0.89 0.08]
# Surfer Dude [0.   0.03 0.89 0.08]
# Surfer Dude [0.   0.03 0.89 0.08]
# Surfer Dude [0.   0.03 0.89 0.08]
# Surfer Dude [0.   0.02 0.9  0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.01 0.92 0.07]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.91 0.08]
# Surfer Dude [0.   0.01 0.9  0.09]
# Surfer Dude [0.   0.02 0.89 0.09]
# Surfer Dude [0.   0.01 0.9  0.09]
# Surfer Dude [0.   0.01 0.9  0.09]
# Surfer Dude [0.   0.01 0.92 0.07]
# Surfer Dude [0.   0.   0.93 0.07]
# Surfer Dude [0.   0.   0.92 0.08]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.01 0.03 0.81 0.15]
# Surfer Dude [0.   0.   0.91 0.09]
# Surfer Dude [0.   0.   0.84 0.16]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.02 0.87 0.11]
# Surfer Dude [0.   0.03 0.86 0.11]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.01 0.86 0.13]
# Surfer Dude [0.   0.01 0.85 0.14]
# Surfer Dude [0.   0.01 0.87 0.12]
# Surfer Dude [0.   0.01 0.85 0.14]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.01 0.89 0.1 ]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.01 0.88 0.11]
# Surfer Dude [0.   0.   0.88 0.12]
# Surfer Dude [0.   0.   0.89 0.11]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.   0.01 0.85 0.14]
# Surfer Dude [0.   0.   0.89 0.11]
# Surfer Dude [0.2  0.23 0.36 0.21]
# Surfer Dude [0.19 0.23 0.38 0.2 ]
# Surfer Dude [0.21 0.21 0.38 0.2 ]
# Surfer Dude [0.22 0.21 0.38 0.19]
# Surfer Dude [0.16 0.24 0.38 0.22]
# Surfer Dude [0.23 0.23 0.35 0.19]
# Surfer Dude [0.24 0.24 0.48 0.04]
# Happy [0.34 0.16 0.27 0.23]
# Surfer Dude [0.32 0.12 0.37 0.19]
# Surfer Dude [0.07 0.12 0.78 0.03]
# Surfer Dude [0.24 0.21 0.5  0.05]
# Surfer Dude [0.35 0.11 0.45 0.09]
# Happy [0.34 0.21 0.26 0.19]
# Surfer Dude [0.17 0.24 0.51 0.08]
# Happy [0.45 0.14 0.25 0.16]
# Surfer Dude [0.24 0.23 0.42 0.11]
# Happy [0.52 0.26 0.17 0.05]
# Happy [0.52 0.26 0.14 0.08]
# Happy [0.47 0.16 0.22 0.15]
# Happy [0.53 0.1  0.23 0.14]
# Happy [0.36 0.1  0.35 0.19]
# Happy [0.43 0.13 0.26 0.18]
# Happy [0.42 0.14 0.26 0.18]
# Surfer Dude [0.  0.  0.9 0.1]
# Surfer Dude [0.07 0.12 0.59 0.22]
# Wakanda Forever [0.1  0.16 0.3  0.44]
# Wakanda Forever [0.08 0.32 0.27 0.33]
# Happy [0.66 0.28 0.04 0.02]
# Happy [0.61 0.31 0.05 0.03]
# Happy [0.66 0.31 0.01 0.02]
# Happy [0.7  0.24 0.03 0.03]
# Happy [0.68 0.2  0.09 0.03]
# Happy [0.63 0.27 0.09 0.01]
# Happy [0.72 0.22 0.04 0.02]
# Happy [0.61 0.34 0.04 0.01]
# Happy [0.55 0.39 0.06 0.  ]
# Happy [0.55 0.4  0.05 0.  ]
# Happy [0.52 0.25 0.21 0.02]
# Happy [0.46 0.23 0.22 0.09]
# Happy [0.54 0.21 0.17 0.08]
# Happy [0.63 0.19 0.09 0.09]
# Happy [0.7  0.16 0.07 0.07]
# Happy [0.78 0.11 0.05 0.06]
# Happy [0.72 0.2  0.04 0.04]
# Happy [0.7  0.22 0.04 0.04]
# Happy [0.68 0.26 0.04 0.02]
# Happy [0.72 0.22 0.04 0.02]
# Happy [0.86 0.1  0.03 0.01]
# Happy [0.87 0.1  0.02 0.01]
# Happy [0.89 0.08 0.02 0.01]
# Happy [0.9  0.07 0.02 0.01]
# Happy [0.89 0.08 0.02 0.01]
# Happy [0.87 0.1  0.02 0.01]
# Happy [0.88 0.09 0.02 0.01]
# Happy [0.86 0.12 0.02 0.  ]
# Happy [0.74 0.24 0.02 0.  ]
# Happy [0.62 0.33 0.05 0.  ]
# Happy [0.6  0.34 0.06 0.  ]
# Happy [0.61 0.31 0.08 0.  ]
# Happy [0.6 0.3 0.1 0. ]
# Happy [0.6  0.29 0.11 0.  ]
# Happy [0.6  0.28 0.12 0.  ]
# Happy [0.59 0.3  0.11 0.  ]
# Happy [0.71 0.16 0.11 0.02]
# Happy [0.73 0.15 0.11 0.01]
# Happy [0.75 0.15 0.08 0.02]
# Happy [0.82 0.11 0.04 0.03]
# Happy [0.84 0.11 0.04 0.01]
# Happy [0.7  0.2  0.06 0.04]
# Happy [0.46 0.35 0.05 0.14]
# Happy [0.48 0.35 0.03 0.14]
# Happy [0.46 0.37 0.03 0.14]
# Happy [0.49 0.34 0.03 0.14]
# Happy [0.47 0.36 0.03 0.14]
# Happy [0.46 0.37 0.03 0.14]
# Happy [0.46 0.38 0.03 0.13]
# Happy [0.54 0.35 0.03 0.08]
# Happy [0.49 0.42 0.03 0.06]
# Happy [0.55 0.38 0.03 0.04]
# Happy [0.58 0.37 0.02 0.03]
# Sad [0.39 0.45 0.05 0.11]
# Wakanda Forever [0.11 0.37 0.08 0.44]
# Surfer Dude [0.18 0.15 0.6  0.07]
# Surfer Dude [0.19 0.15 0.55 0.11]
# Surfer Dude [0.32 0.14 0.43 0.11]
# Surfer Dude [0.38 0.14 0.4  0.08]
# Surfer Dude [0.24 0.13 0.49 0.14]
# Surfer Dude [0.19 0.13 0.58 0.1 ]
# Surfer Dude [0.25 0.14 0.51 0.1 ]
# Surfer Dude [0.25 0.15 0.5  0.1 ]
# Surfer Dude [0.3  0.12 0.48 0.1 ]
# Surfer Dude [0.3  0.19 0.45 0.06]
# Surfer Dude [0.26 0.2  0.48 0.06]
# Surfer Dude [0.18 0.23 0.49 0.1 ]
# Surfer Dude [0.1  0.2  0.57 0.13]
# Surfer Dude [0.11 0.2  0.56 0.13]
# Surfer Dude [0.24 0.23 0.43 0.1 ]
# Surfer Dude [0.28 0.17 0.45 0.1 ]
# Surfer Dude [0.27 0.13 0.51 0.09]
# Surfer Dude [0.23 0.21 0.49 0.07]
# Surfer Dude [0.21 0.19 0.54 0.06]
# Surfer Dude [0.28 0.19 0.46 0.07]
# Happy [0.61 0.27 0.03 0.09]
# Happy [0.64 0.26 0.02 0.08]
# Happy [0.63 0.27 0.02 0.08]
# Happy [0.73 0.21 0.01 0.05]
# Happy [0.65 0.27 0.03 0.05]
# Happy [0.68 0.25 0.02 0.05]
# Happy [0.71 0.24 0.03 0.02]
# Happy [0.52 0.37 0.04 0.07]
# Happy [0.5  0.39 0.02 0.09]
# Happy [0.5  0.38 0.04 0.08]
# Happy [0.56 0.33 0.05 0.06]
# Happy [0.73 0.24 0.03 0.  ]
# Happy [0.73 0.24 0.03 0.  ]
# Happy [0.53 0.37 0.04 0.06]
# Happy [0.53 0.36 0.04 0.07]
# Happy [0.53 0.35 0.05 0.07]
# Happy [0.53 0.38 0.04 0.05]
# Happy [0.62 0.32 0.03 0.03]
# Happy [0.53 0.36 0.04 0.07]
# Happy [0.56 0.31 0.05 0.08]
# Happy [0.57 0.29 0.05 0.09]
# Happy [0.55 0.34 0.05 0.06]
# Happy [0.59 0.33 0.04 0.04]
# Happy [0.53 0.37 0.05 0.05]
# Happy [0.6  0.34 0.03 0.03]
# Happy [0.54 0.33 0.05 0.08]
# Happy [0.46 0.24 0.18 0.12]
# Happy [0.4  0.19 0.32 0.09]
# Happy [0.38 0.2  0.33 0.09]
# Happy [0.35 0.22 0.34 0.09]
# Happy [0.37 0.23 0.33 0.07]
# Happy [0.42 0.29 0.18 0.11]
# Happy [0.43 0.29 0.18 0.1 ]
# Happy [0.41 0.3  0.19 0.1 ]
# Happy [0.41 0.28 0.17 0.14]
# Happy [0.37 0.31 0.23 0.09]
# Happy [0.45 0.28 0.19 0.08]
# Happy [0.63 0.23 0.13 0.01]
# Happy [0.65 0.22 0.12 0.01]
# Happy [0.5  0.28 0.14 0.08]
# Happy [0.51 0.29 0.11 0.09]
# Happy [0.5  0.25 0.11 0.14]
# Happy [0.5  0.27 0.12 0.11]
# Happy [0.49 0.28 0.13 0.1 ]
# Happy [0.49 0.28 0.13 0.1 ]
# Happy [0.57 0.25 0.11 0.07]
# Happy [0.52 0.26 0.11 0.11]
# Happy [0.55 0.25 0.11 0.09]
# Happy [0.56 0.22 0.09 0.13]
# Happy [0.6  0.2  0.08 0.12]
# Happy [0.62 0.23 0.07 0.08]
# Happy [0.62 0.24 0.07 0.07]
# Happy [0.62 0.21 0.08 0.09]
# Happy [0.79 0.17 0.03 0.01]
# Happy [0.8  0.16 0.03 0.01]
# Happy [0.75 0.18 0.02 0.05]
# Happy [0.67 0.24 0.03 0.06]
# Happy [0.64 0.28 0.02 0.06]
# Happy [0.59 0.33 0.02 0.06]
# Happy [0.58 0.36 0.01 0.05]
# Happy [0.64 0.28 0.02 0.06]
# Happy [0.69 0.27 0.02 0.02]
# Happy [0.72 0.25 0.01 0.02]
# Happy [0.8  0.19 0.01 0.  ]
# Happy [0.79 0.2  0.01 0.  ]
# Happy [0.79 0.2  0.01 0.  ]
# Happy [0.78 0.21 0.01 0.  ]
# Happy [0.79 0.2  0.01 0.  ]
# Happy [0.78 0.21 0.01 0.  ]
# Happy [0.78 0.21 0.01 0.  ]
# Happy [0.8  0.19 0.01 0.  ]
# Happy [0.8  0.19 0.01 0.  ]
# Happy [0.81 0.18 0.01 0.  ]
# Happy [0.8  0.19 0.01 0.  ]
# Happy [0.82 0.17 0.01 0.  ]
# Happy [0.8  0.19 0.01 0.  ]
# Happy [0.82 0.17 0.01 0.  ]
# Happy [0.8  0.19 0.01 0.  ]
# Happy [0.8  0.19 0.01 0.  ]
# Happy [0.79 0.2  0.01 0.  ]
# Happy [0.79 0.2  0.01 0.  ]
# Happy [0.67 0.24 0.07 0.02]
# Happy [0.66 0.21 0.06 0.07]
# Happy [0.61 0.22 0.1  0.07]
# Happy [0.78 0.16 0.04 0.02]
# Happy [0.84 0.12 0.02 0.02]
# Happy [0.89 0.06 0.03 0.02]
# Happy [0.9  0.05 0.03 0.02]
# Happy [0.9  0.06 0.03 0.01]
# Happy [0.8  0.11 0.03 0.06]
# Happy [0.89 0.08 0.03 0.  ]
# Happy [0.88 0.08 0.04 0.  ]
# Happy [0.84 0.11 0.05 0.  ]
# Happy [0.54 0.24 0.16 0.06]
# Happy [0.53 0.27 0.14 0.06]
# Happy [0.68 0.22 0.07 0.03]
# Happy [0.73 0.2  0.03 0.04]
# Happy [0.82 0.16 0.01 0.01]
# Happy [0.84 0.15 0.01 0.  ]
# Happy [0.56 0.21 0.08 0.15]
# Happy [0.58 0.28 0.08 0.06]
# Happy [0.77 0.19 0.03 0.01]
# Happy [0.76 0.2  0.03 0.01]
# Happy [0.74 0.22 0.01 0.03]
# Happy [0.57 0.28 0.04 0.11]
# Happy [0.72 0.2  0.04 0.04]
# Happy [0.74 0.19 0.02 0.05]
# Happy [0.76 0.18 0.02 0.04]
# Happy [0.75 0.18 0.02 0.05]
# Happy [0.72 0.21 0.02 0.05]
# Happy [0.72 0.2  0.03 0.05]
# Happy [0.71 0.21 0.03 0.05]
# Happy [0.72 0.21 0.02 0.05]
# Happy [0.73 0.19 0.03 0.05]
# Happy [0.76 0.18 0.03 0.03]
# Happy [0.77 0.17 0.03 0.03]
# Happy [0.77 0.17 0.03 0.03]
# Happy [0.79 0.16 0.02 0.03]
# Happy [0.78 0.15 0.03 0.04]
# Happy [0.77 0.17 0.03 0.03]
# Happy [0.79 0.15 0.03 0.03]
# Happy [0.77 0.18 0.03 0.02]
# Happy [0.78 0.18 0.03 0.01]
# Happy [0.78 0.18 0.03 0.01]
# Happy [0.77 0.18 0.03 0.02]
# Happy [0.78 0.18 0.03 0.01]
# Happy [0.81 0.14 0.04 0.01]
# Happy [0.79 0.14 0.04 0.03]
# Happy [0.74 0.2  0.03 0.03]
# Happy [0.72 0.24 0.02 0.02]
# Sad [0.21 0.44 0.11 0.24]
# Happy [0.4  0.37 0.14 0.09]
# Happy [0.37 0.35 0.18 0.1 ]
# Happy [0.44 0.33 0.16 0.07]
# Happy [0.48 0.37 0.09 0.06]
# Happy [0.57 0.31 0.03 0.09]
# Happy [0.56 0.34 0.03 0.07]
# Happy [0.67 0.26 0.01 0.06]
# Happy [0.68 0.25 0.02 0.05]
# Happy [0.66 0.28 0.02 0.04]
# Happy [0.62 0.33 0.03 0.02]
# Happy [0.6  0.36 0.02 0.02]
# Happy [0.59 0.36 0.02 0.03]
# Happy [0.61 0.35 0.02 0.02]
# Happy [0.63 0.3  0.02 0.05]
# Happy [0.65 0.27 0.02 0.06]
# Happy [0.63 0.28 0.03 0.06]
# Happy [0.63 0.29 0.03 0.05]
# Happy [0.64 0.28 0.03 0.05]
# Happy [0.65 0.26 0.03 0.06]
# Happy [0.58 0.3  0.06 0.06]
# Happy [0.56 0.29 0.1  0.05]
# Happy [0.53 0.24 0.11 0.12]
# Sad [0.25 0.49 0.07 0.19]
# Surfer Dude [0.2  0.24 0.38 0.18]
# Happy [0.57 0.2  0.11 0.12]
# Happy [0.62 0.23 0.07 0.08]
# Happy [0.65 0.24 0.05 0.06]
# Happy [0.56 0.27 0.13 0.04]
# Happy [0.66 0.2  0.06 0.08]
# Happy [0.52 0.3  0.09 0.09]
# Happy [0.57 0.29 0.08 0.06]
# Happy [0.55 0.29 0.06 0.1 ]
# Happy [0.63 0.33 0.02 0.02]
# Happy [0.7  0.28 0.01 0.01]
# Happy [0.71 0.25 0.02 0.02]
# Happy [0.71 0.25 0.02 0.02]
# Happy [0.7  0.28 0.01 0.01]
# Happy [0.71 0.25 0.02 0.02]
# Happy [0.72 0.22 0.03 0.03]
# Happy [0.72 0.22 0.03 0.03]
# Happy [0.72 0.24 0.02 0.02]
# Happy [0.73 0.25 0.01 0.01]
# Happy [0.71 0.27 0.01 0.01]
# Happy [0.73 0.24 0.02 0.01]
# ...
# Sad [0.31 0.4  0.12 0.17]
# Sad [0.31 0.4  0.12 0.17]
# Sad [0.31 0.41 0.12 0.16]
# Sad [0.31 0.41 0.12 0.16]
# Sad [0.31 0.4  0.13 0.16]
# Sad [0.31 0.41 0.12 0.16]
# Sad [0.31 0.41 0.12 0.16]
# Sad [0.31 0.43 0.11 0.15]
# Sad [0.31 0.44 0.1  0.15]
# Sad [0.31 0.43 0.11 0.15]
# Sad [0.31 0.43 0.11 0.15]
# Sad [0.32 0.43 0.1  0.15]
# Sad [0.31 0.43 0.11 0.15]
# Sad [0.32 0.41 0.11 0.16]
# Sad [0.33 0.41 0.1  0.16]
# Sad [0.33 0.41 0.1  0.16]
# Sad [0.33 0.4  0.11 0.16]
# Sad [0.33 0.4  0.11 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.33 0.4  0.11 0.16]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.33 0.42 0.11 0.14]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.32 0.42 0.12 0.14]
# Sad [0.32 0.42 0.12 0.14]
# Sad [0.32 0.42 0.12 0.14]
# Sad [0.32 0.42 0.12 0.14]
# Sad [0.31 0.41 0.12 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.43 0.12 0.16]
# Sad [0.29 0.43 0.12 0.16]
# Sad [0.29 0.43 0.12 0.16]
# Sad [0.29 0.43 0.12 0.16]
# Sad [0.29 0.43 0.12 0.16]
# Sad [0.29 0.43 0.12 0.16]
# Sad [0.29 0.43 0.12 0.16]
# Sad [0.29 0.43 0.12 0.16]
# Sad [0.29 0.43 0.12 0.16]
# Sad [0.29 0.43 0.12 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.43 0.1  0.17]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.29 0.45 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.29 0.45 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.29 0.45 0.1  0.16]
# Sad [0.29 0.47 0.1  0.14]
# Sad [0.3  0.46 0.1  0.14]
# Sad [0.3  0.46 0.1  0.14]
# Sad [0.3  0.46 0.1  0.14]
# Sad [0.3  0.46 0.1  0.14]
# Sad [0.3  0.46 0.1  0.14]
# Sad [0.3  0.46 0.1  0.14]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.28 0.45 0.11 0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.28 0.45 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.28 0.45 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.28 0.45 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.29 0.44 0.11 0.16]
# Sad [0.32 0.4  0.12 0.16]
# Sad [0.31 0.42 0.12 0.15]
# Sad [0.31 0.42 0.12 0.15]
# Sad [0.32 0.46 0.1  0.12]
# Sad [0.32 0.45 0.1  0.13]
# Sad [0.32 0.45 0.1  0.13]
# Sad [0.32 0.44 0.1  0.14]
# Sad [0.32 0.45 0.1  0.13]
# Sad [0.32 0.45 0.1  0.13]
# Sad [0.32 0.44 0.1  0.14]
# Sad [0.31 0.45 0.1  0.14]
# Sad [0.3  0.44 0.1  0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.32 0.42 0.1  0.16]
# Sad [0.31 0.43 0.11 0.15]
# Sad [0.32 0.45 0.1  0.13]
# Sad [0.32 0.44 0.1  0.14]
# Sad [0.32 0.43 0.1  0.15]
# Sad [0.32 0.41 0.13 0.14]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.29 0.47 0.1  0.14]
# Sad [0.29 0.47 0.1  0.14]
# Sad [0.29 0.47 0.1  0.14]
# Sad [0.29 0.47 0.1  0.14]
# Sad [0.29 0.45 0.13 0.13]
# Sad [0.29 0.45 0.13 0.13]
# Sad [0.29 0.46 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.31 0.42 0.12 0.15]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.41 0.11 0.16]
# Sad [0.32 0.4  0.13 0.15]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.32 0.43 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.42 0.13 0.14]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.41 0.13 0.15]
# Sad [0.32 0.42 0.1  0.16]
# Sad [0.32 0.42 0.1  0.16]
# Sad [0.32 0.42 0.1  0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.32 0.42 0.1  0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.31 0.42 0.11 0.16]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.12 0.13]
# Sad [0.31 0.44 0.12 0.13]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.44 0.12 0.13]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.32 0.39 0.13 0.16]
# Sad [0.32 0.41 0.13 0.14]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.32 0.4  0.13 0.15]
# Sad [0.32 0.4  0.13 0.15]
# Sad [0.32 0.41 0.13 0.14]
# Sad [0.31 0.42 0.13 0.14]
# Sad [0.32 0.4  0.13 0.15]
# Sad [0.31 0.41 0.13 0.15]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.42 0.13 0.14]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.43 0.13 0.13]
# Sad [0.31 0.44 0.12 0.13]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.44 0.11 0.14]
# Sad [0.31 0.43 0.11 0.15]
# Sad [0.32 0.42 0.11 0.15]
# Sad [0.32 0.41 0.12 0.15]
# Sad [0.32 0.4  0.13 0.15]
# Sad [0.32 0.39 0.12 0.17]
# Sad [0.32 0.4  0.11 0.17]
# Sad [0.31 0.39 0.11 0.19]
# Sad [0.31 0.39 0.11 0.19]
# Sad [0.31 0.38 0.13 0.18]
# Sad [0.31 0.39 0.11 0.19]
# Sad [0.31 0.39 0.11 0.19]
# Sad [0.32 0.39 0.1  0.19]
# Sad [0.32 0.39 0.1  0.19]
# Sad [0.32 0.4  0.1  0.18]
# Sad [0.32 0.39 0.1  0.19]
# Sad [0.32 0.4  0.1  0.18]
# Sad [0.32 0.4  0.1  0.18]
# Sad [0.32 0.39 0.12 0.17]
# Sad [0.32 0.39 0.12 0.17]
# Sad [0.32 0.39 0.12 0.17]
# Sad [0.32 0.39 0.12 0.17]
# Sad [0.32 0.39 0.12 0.17]
# Sad [0.31 0.39 0.14 0.16]
# Sad [0.33 0.38 0.12 0.17]
# Sad [0.33 0.38 0.12 0.17]
# Sad [0.33 0.38 0.12 0.17]
# Sad [0.33 0.38 0.12 0.17]
# Sad [0.33 0.38 0.12 0.17]
# Sad [0.33 0.39 0.12 0.16]
# Sad [0.31 0.4  0.14 0.15]
# Sad [0.31 0.4  0.14 0.15]
# Sad [0.31 0.4  0.14 0.15]
# Sad [0.31 0.4  0.14 0.15]
# Sad [0.31 0.41 0.15 0.13]
# Sad [0.32 0.42 0.14 0.12]
# Sad [0.32 0.42 0.14 0.12]
# Sad [0.32 0.42 0.13 0.13]
# Sad [0.29 0.44 0.14 0.13]
# Sad [0.29 0.44 0.14 0.13]
# Sad [0.28 0.44 0.15 0.13]
# Sad [0.28 0.45 0.14 0.13]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.43 0.14 0.14]
# Sad [0.29 0.43 0.14 0.14]
# Sad [0.29 0.43 0.14 0.14]
# Sad [0.29 0.43 0.14 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.45 0.12 0.14]
# Sad [0.29 0.45 0.12 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.29 0.44 0.13 0.14]
# Sad [0.3  0.38 0.16 0.16]
# Sad [0.3  0.44 0.13 0.13]
# Sad [0.29 0.44 0.15 0.12]
# Sad [0.3  0.44 0.14 0.12]
# Sad [0.29 0.43 0.16 0.12]
# Sad [0.3  0.42 0.16 0.12]
# Sad [0.3  0.4  0.17 0.13]
# Sad [0.3  0.34 0.2  0.16]
# Sad [0.34 0.37 0.14 0.15]
# Sad [0.33 0.4  0.11 0.16]
# Sad [0.37 0.5  0.06 0.07]
# Happy [0.52 0.41 0.04 0.03]
# Happy [0.52 0.41 0.04 0.03]
# Happy [0.55 0.24 0.13 0.08]
# Happy [0.52 0.34 0.05 0.09]
# Happy [0.57 0.32 0.04 0.07]
# Happy [0.57 0.32 0.04 0.07]
# Happy [0.63 0.28 0.04 0.05]
# Happy [0.61 0.31 0.03 0.05]
# Happy [0.53 0.37 0.04 0.06]
# Happy [0.62 0.27 0.05 0.06]
# Happy [0.68 0.23 0.05 0.04]
# Happy [0.67 0.2  0.04 0.09]
# Happy [0.66 0.25 0.02 0.07]
# Happy [0.36 0.17 0.3  0.17]
# Surfer Dude [0.3  0.14 0.39 0.17]
# Happy [0.38 0.17 0.27 0.18]
# Happy [0.52 0.16 0.19 0.13]
# Happy [0.41 0.29 0.19 0.11]
# Happy [0.41 0.3  0.19 0.1 ]
# Happy [0.42 0.33 0.17 0.08]
# Happy [0.48 0.19 0.19 0.14]
# Happy [0.46 0.16 0.25 0.13]
# Happy [0.39 0.16 0.34 0.11]
# Happy [0.37 0.17 0.34 0.12]
# Happy [0.34 0.2  0.34 0.12]
# Happy [0.34 0.2  0.33 0.13]
# Happy [0.35 0.23 0.3  0.12]
# Happy [0.37 0.22 0.29 0.12]
# Happy [0.38 0.25 0.26 0.11]
# Happy [0.41 0.28 0.22 0.09]
# Happy [0.61 0.25 0.12 0.02]
# Happy [0.58 0.27 0.12 0.03]
# Happy [0.5  0.36 0.11 0.03]
# Happy [0.6  0.27 0.1  0.03]
# Happy [0.6  0.3  0.09 0.01]
# Happy [0.59 0.32 0.08 0.01]
# Happy [0.6  0.32 0.07 0.01]
# Happy [0.6  0.31 0.07 0.02]
# Happy [0.62 0.29 0.07 0.02]
# Happy [0.63 0.28 0.07 0.02]
# Happy [0.73 0.23 0.04 0.  ]
# Happy [0.74 0.24 0.02 0.  ]
# Happy [0.68 0.3  0.01 0.01]
# Happy [0.63 0.26 0.07 0.04]
# Happy [0.61 0.26 0.08 0.05]
# Happy [0.62 0.27 0.06 0.05]
# Happy [0.68 0.26 0.03 0.03]
# Happy [0.66 0.26 0.06 0.02]
# Happy [0.63 0.29 0.06 0.02]
# Happy [0.66 0.27 0.05 0.02]
# Happy [0.62 0.31 0.05 0.02]
# Happy [0.67 0.29 0.03 0.01]
# Happy [0.69 0.28 0.02 0.01]
# Happy [0.7  0.28 0.02 0.  ]
# Happy [0.71 0.27 0.02 0.  ]
# Happy [0.73 0.25 0.02 0.  ]
# Happy [0.73 0.25 0.02 0.  ]
# Happy [0.76 0.22 0.02 0.  ]
# Happy [0.78 0.19 0.02 0.01]
# Happy [0.79 0.18 0.02 0.01]
# Happy [0.81 0.17 0.02 0.  ]
# Happy [0.8  0.18 0.02 0.  ]
# Happy [0.8  0.18 0.02 0.  ]
# Happy [0.78 0.18 0.03 0.01]
# Happy [0.8  0.16 0.03 0.01]
# Happy [0.8  0.16 0.03 0.01]
# Happy [0.8  0.16 0.03 0.01]
# Happy [0.81 0.15 0.03 0.01]
# Happy [0.82 0.13 0.03 0.02]
# Happy [0.83 0.12 0.03 0.02]
# Happy [0.81 0.14 0.03 0.02]
# Happy [0.79 0.12 0.05 0.04]
# Happy [0.74 0.12 0.09 0.05]
# Happy [0.83 0.15 0.02 0.  ]
# Happy [0.77 0.21 0.02 0.  ]
# Happy [0.67 0.3  0.03 0.  ]
# Happy [0.68 0.28 0.04 0.  ]
# Happy [0.69 0.26 0.04 0.01]
# Happy [0.69 0.26 0.02 0.03]
# Happy [0.61 0.27 0.05 0.07]
# Happy [0.68 0.24 0.03 0.05]
# Happy [0.72 0.26 0.01 0.01]
# Happy [0.64 0.29 0.03 0.04]
# Happy [0.68 0.3  0.01 0.01]
# Happy [0.67 0.3  0.01 0.02]
# Happy [0.69 0.26 0.01 0.04]
# Happy [0.8  0.15 0.02 0.03]
# Happy [0.84 0.09 0.04 0.03]
# Happy [0.84 0.09 0.03 0.04]
# Happy [0.86 0.1  0.02 0.02]
# Happy [0.86 0.09 0.03 0.02]
# Happy [0.86 0.1  0.02 0.02]
# Happy [0.85 0.11 0.02 0.02]
# Happy [0.75 0.21 0.04 0.  ]
# Happy [0.7  0.25 0.04 0.01]
# Happy [0.74 0.17 0.05 0.04]
# Happy [0.63 0.33 0.04 0.  ]
# Happy [0.59 0.28 0.08 0.05]
# Happy [0.59 0.22 0.09 0.1 ]
# Happy [0.57 0.26 0.1  0.07]
# Happy [0.62 0.22 0.06 0.1 ]
# Happy [0.61 0.23 0.06 0.1 ]
# Happy [0.63 0.21 0.05 0.11]
# Happy [0.68 0.19 0.06 0.07]
# Happy [0.7  0.19 0.04 0.07]
# Happy [0.7  0.2  0.04 0.06]
# Happy [0.7  0.2  0.04 0.06]
# Happy [0.71 0.21 0.04 0.04]
# Happy [0.72 0.18 0.04 0.06]
# Happy [0.72 0.2  0.03 0.05]
# Happy [0.73 0.19 0.03 0.05]
# Happy [0.74 0.21 0.01 0.04]
# Happy [0.77 0.18 0.01 0.04]
# Happy [0.78 0.17 0.02 0.03]
# Happy [0.53 0.36 0.03 0.08]
# Happy [0.7  0.25 0.01 0.04]
# Happy [0.69 0.27 0.01 0.03]
# Happy [0.64 0.3  0.01 0.05]
# Happy [0.67 0.28 0.01 0.04]
# Happy [0.69 0.26 0.01 0.04]
# Happy [0.54 0.37 0.02 0.07]
# Happy [0.48 0.37 0.02 0.13]
# Happy [0.59 0.3  0.02 0.09]
# Happy [0.6  0.32 0.01 0.07]
# Happy [0.48 0.43 0.02 0.07]
# Happy [0.46 0.41 0.04 0.09]
# Sad [0.39 0.45 0.05 0.11]
# Sad [0.4  0.43 0.05 0.12]
# Sad [0.35 0.42 0.13 0.1 ]
# Happy [0.45 0.31 0.15 0.09]
# Happy [0.46 0.32 0.15 0.07]
# Happy [0.45 0.31 0.15 0.09]
# Sad [0.35 0.38 0.15 0.12]
# Happy [0.4  0.39 0.14 0.07]
# Sad [0.4  0.41 0.14 0.05]
# Happy [0.47 0.37 0.12 0.04]
# Happy [0.75 0.15 0.04 0.06]
# Happy [0.58 0.27 0.13 0.02]
# Happy [0.6  0.24 0.13 0.03]
# Happy [0.62 0.21 0.13 0.04]
# Happy [0.61 0.22 0.1  0.07]
# Happy [0.58 0.27 0.06 0.09]
# Happy [0.61 0.25 0.06 0.08]
# Happy [0.7  0.21 0.04 0.05]
# Happy [0.61 0.31 0.04 0.04]
# Happy [0.52 0.37 0.02 0.09]
# Happy [0.59 0.27 0.04 0.1 ]
# Happy [0.59 0.3  0.04 0.07]
# Happy [0.74 0.17 0.04 0.05]
# Happy [0.73 0.17 0.04 0.06]
# Happy [0.74 0.22 0.02 0.02]
# Happy [0.77 0.21 0.02 0.  ]
# Happy [0.75 0.23 0.02 0.  ]
# Happy [0.7  0.21 0.02 0.07]
# Happy [0.73 0.24 0.02 0.01]
# Happy [0.76 0.22 0.02 0.  ]
# Happy [0.79 0.19 0.02 0.  ]
# Happy [0.79 0.18 0.03 0.  ]
# Happy [0.8  0.17 0.03 0.  ]
# Happy [0.8  0.17 0.03 0.  ]
# Happy [0.67 0.3  0.02 0.01]
# Happy [0.69 0.28 0.02 0.01]
# Happy [0.73 0.24 0.02 0.01]
# Happy [0.68 0.29 0.02 0.01]
# Happy [0.66 0.29 0.02 0.03]
# Happy [0.77 0.21 0.02 0.  ]

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (469, 191)
