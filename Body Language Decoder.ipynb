# %% [markdown]
# # 0. Install and Import Dependencies

# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (0.8.4.2)
# Requirement already satisfied: opencv-python in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (4.3.0.36)
# Requirement already satisfied: pandas in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (1.0.5)
# Requirement already satisfied: scikit-learn in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (0.23.1)
# Requirement already satisfied: protobuf>=3.11.4 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (3.12.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (4.5.2.52)
# Requirement already satisfied: wheel in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (0.34.2)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (19.3.0)
# Requirement already satisfied: six in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (1.15.0)
# Requirement already satisfied: numpy in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (1.19.0)
# Requirement already satisfied: absl-py in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (0.9.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (0.16.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: setuptools in c:\users\roble\appdata\local\programs\python\python38\lib\site-packages (from protobuf>=3.11.4->mediapipe) (41.2.0)
# The system cannot find the path specified.
# WARNING: You are using pip version 20.2.4; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\roble\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv
import csv

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Make Some Detections

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-07452023dcb3> in <module>
#       1 with open('coords.csv', mode='w', newline='') as f:
#       2     csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
# ----> 3     csv_writer.writerow(landmarks)
#
# NameError: name 'landmarks' is not defined

# %% [markdown]
# Webcam version

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# Youtube Video Version

# %%
vids = [{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "70311", "cend": "72063"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "539016", "cend": "539746"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "558453", "cend": "558966"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "578393", "cend": "579337"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "582497", "cend": "583735"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "584176", "cend": "584677"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "585752", "cend": "586112"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "595601", "cend": "596045"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "597100", "cend": "597559"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "602642", "cend": "602957"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "606490", "cend": "607434"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "618813", "cend": "619334"},
{"cID": "EdVueeaNAK0", "title": "Ollie", "cstart": "630671", "cend": "632162"},
{"cID": "KJnZvKwgZaA", "title": "Ollie", "cstart": "16015", "cend": "21669"},
{"cID": "KJnZvKwgZaA", "title": "Ollie", "cstart": "28784", "cend": "33723"},
{"cID": "KJnZvKwgZaA", "title": "Ollie", "cstart": "100735", "cend": "105913"},
{"cID": "KJnZvKwgZaA", "title": "Ollie", "cstart": "121867", "cend": "126552"},
{"cID": "KJnZvKwgZaA", "title": "Ollie", "cstart": "159667", "cend": "161173"},
{"cID": "KJnZvKwgZaA", "title": "Ollie", "cstart": "161497", "cend": "165076"},
{"cID": "KJnZvKwgZaA", "title": "Ollie", "cstart": "165590", "cend": "169727"},
{"cID": "KJnZvKwgZaA", "title": "Ollie", "cstart": "178468", "cend": "180045"},
{"cID": "KJnZvKwgZaA", "title": "Ollie", "cstart": "182830", "cend": "188237"},
{"cID": "KJnZvKwgZaA", "title": "Ollie", "cstart": "195547", "cend": "199861"},
{"cID": "fp_UMkZabvk", "title": "Nollie", "cstart": "6442", "cend": "13078"},
{"cID": "9siogRgZo3Y", "title": "Kickflip", "cstart": "9656", "cend": "13143"},
{"cID": "9siogRgZo3Y", "title": "Kickflip", "cstart": "32169", "cend": "34800"},
{"cID": "9siogRgZo3Y", "title": "Kickflip", "cstart": "55760", "cend": "59292"},
{"cID": "9siogRgZo3Y", "title": "Kickflip", "cstart": "204266", "cend": "207530"},
{"cID": "9siogRgZo3Y", "title": "Kickflip", "cstart": "277463", "cend": "280556"}]

# %%
vids = [{"cID": "qZEElv92rLM", "title": "Onda Onda", "cstart": "35137", "cend": "42571"},
{"cID": "qZEElv92rLM", "title": "Controller Crew", "cstart": "110635", "cend": "112780"},
{"cID": "qZEElv92rLM", "title": "Hit It", "cstart": "120177", "cend": "132160"},
{"cID": "qZEElv92rLM", "title": "Billy Bounce", "cstart": "154580", "cend": "160941"},
{"cID": "qZEElv92rLM", "title": "Dont' Start Now", "cstart": "175213", "cend": "188833"},
{"cID": "qZEElv92rLM", "title": "Savage", "cstart": "197961", "cend": "211121"},
{"cID": "qZEElv92rLM", "title": "The Flow", "cstart": "221555", "cend": "231141"},
{"cID": "qZEElv92rLM", "title": "The Flow", "cstart": "233278", "cend": "238461"}]

# %%
import pafy, cv2, json, math
# url = 'https://youtu.be/DK797d9ozN0?t=440'

class Vid_Stream():
    def __init__(self,vids,output_file,options = None):
        self.yt_url = 'https://www.youtube.com/watch?v='
        self.vids = vids
        out = cv2.VideoWriter(output_file + '.mp4',cv2.VideoWriter_fourcc(*'MP4V'), 30, (640,480))
        if not options is None:
            self.options = json.loads(options)
        else:
            self.options = json.loads("""{"side":"both"}""")
            
            

        for vid in self.vids:
            vPafy = pafy.new(self.yt_url + vid['cID'])
            play = vPafy.getbest(preftype="mp4")
            cap = cv2.VideoCapture(play.url)
            cap.set(cv2.CAP_PROP_POS_MSEC, int(vid['cstart']))
            # Initiate holistic model
            with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

                while cap.isOpened():
                    ret, frame = cap.read()
                    

                    # Recolor Feed
                    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                           
                    height, width, channels = image.shape
                    if self.options['side'] == 'right':
                        image = image[:, math.floor(width/2):width,:]
                        cv2.imwrite('image.jpg',image)
#                     image.flags.writeable = False 
                    # Make Detections
                    results = holistic.process(image)
                    # print(results.face_landmarks)

                    # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks

                    # Recolor image back to BGR for rendering
                    image.flags.writeable = True   
                    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            #         # 1. Draw face landmarks
            #         mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
            #                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
            #                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
            #                                  )

                    # 2. Right hand
                    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                             )

                    # 3. Left Hand
                    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                             )

                    # 4. Pose Detections
                    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                             )
                    # Export coordinates
                    try:
                            # Extract Pose landmarks
                        pose = results.pose_landmarks.landmark
                        pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #                 # Extract Face landmarks
            #                 face = results.face_landmarks.landmark
            #                 face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

                        # Concate rows
                        row = pose_row   #+face_row

                        # Append class name 
                        row.insert(0, vid['title'])

                        # Export to CSV
                        with open('coords.csv', mode='a', newline='') as f:
                            csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                            csv_writer.writerow(row)

                    except:
                        pass

                    cv2.imshow('Trick Maneuver Training video: ' + vid['title'], image)
                    # resize image
                    dim = (640, 480)
                    image = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
                    out.write(image)

                    if cv2.waitKey(10) & 0xFF == ord('q'):
                        break

                    cur_time = cap.get(cv2.CAP_PROP_POS_MSEC)
                    if cur_time > int(vid['cend']):
                        break

            cap.release()
            cv2.destroyAllWindows()
        out.release()

# %%
options="""{"side":"right"}"""
Vid_Stream(vids[:1],'output_file',options=options)

# %% [markdown]
# # 2. Capture Landmarks & Export to CSV
# <!--<img src="https://i.imgur.com/8bForKY.png">-->
# <!--<img src="https://i.imgur.com/AzKNp7A.png">-->

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-1882204c147b> in <module>
# ----> 1 num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
#
# NameError: name 'results' is not defined

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-d533906b7cf0> in <module>
#       1 landmarks = ['class']
# ----> 2 for val in range(1, num_coords+1):
#       3     landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]
#
# NameError: name 'num_coords' is not defined

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %% [markdown]
# # 3. Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 0  Ollie  0.451151  0.144746 -0.372693  0.999985  0.454345  0.124245
# 1  Ollie  0.450804  0.143198 -0.405820  0.999985  0.454168  0.122036
# 2  Ollie  0.448904  0.142284 -0.376282  0.999983  0.452525  0.121078
# 3  Ollie  0.445280  0.138653 -0.368911  0.999983  0.448895  0.118170
# 4  Ollie  0.441117  0.133836 -0.356226  0.999983  0.443727  0.114050
#
#          z2        v2        x3  ...  z499  v499  x500  y500  z500  v500  \
# 0 -0.369818  0.999962  0.458266  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1 -0.399079  0.999964  0.458237  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2 -0.377256  0.999961  0.456613  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3 -0.370954  0.999959  0.452974  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4 -0.360827  0.999958  0.447370  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    x501  y501  z501  v501
# 0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#          class        x1        y1        z1        v1        x2        y2  \
# 1710  Kickflip  0.418214  0.529177 -0.059898  0.995948  0.422488  0.539639
# 1711  Kickflip  0.428246  0.573672 -0.071712  0.995005  0.428015  0.585898
# 1712  Kickflip  0.428274  0.609891 -0.047709  0.994327  0.432353  0.622005
# 1713  Kickflip  0.424670  0.589216 -0.046472  0.993130  0.426713  0.602443
# 1714  Kickflip  0.425220  0.608671 -0.118502  0.992998  0.426985  0.617375
#
#             z2        v2        x3  ...  z499  v499  x500  y500  z500  v500  \
# 1710 -0.049005  0.995392  0.423687  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1711 -0.064052  0.994453  0.427078  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1712 -0.040413  0.993793  0.431292  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1713 -0.032074  0.992739  0.426249  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1714 -0.104623  0.992337  0.426723  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#       x501  y501  z501  v501
# 1710   NaN   NaN   NaN   NaN
# 1711   NaN   NaN   NaN   NaN
# 1712   NaN   NaN   NaN   NaN
# 1713   NaN   NaN   NaN   NaN
# 1714   NaN   NaN   NaN   NaN
#
# [5 rows x 2005 columns]

# %%
df[df['class']=='Ollie']
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 0     Ollie  0.451151  0.144746 -0.372693  0.999985  0.454345  0.124245
# 1     Ollie  0.450804  0.143198 -0.405820  0.999985  0.454168  0.122036
# 2     Ollie  0.448904  0.142284 -0.376282  0.999983  0.452525  0.121078
# 3     Ollie  0.445280  0.138653 -0.368911  0.999983  0.448895  0.118170
# 4     Ollie  0.441117  0.133836 -0.356226  0.999983  0.443727  0.114050
# ...     ...       ...       ...       ...       ...       ...       ...
# 1232  Ollie  0.795810  0.376354 -0.184724  1.000000  0.797854  0.363720
# 1233  Ollie  0.800908  0.379416 -0.180704  1.000000  0.802893  0.366616
# 1234  Ollie  0.803994  0.378902 -0.177126  1.000000  0.805657  0.365659
# 1235  Ollie  0.807984  0.380993 -0.168404  1.000000  0.809752  0.367253
# 1236  Ollie  0.812241  0.384174 -0.172815  1.000000  0.813857  0.369988
#
#             z2        v2        x3  ...  z499  v499  x500  y500  z500  v500  \
# 0    -0.369818  0.999962  0.458266  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1    -0.399079  0.999964  0.458237  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2    -0.377256  0.999961  0.456613  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3    -0.370954  0.999959  0.452974  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4    -0.360827  0.999958  0.447370  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...        ...       ...       ...  ...   ...   ...   ...   ...   ...   ...
# 1232 -0.169202  0.999998  0.797866  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1233 -0.166231  0.999998  0.802851  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1234 -0.162701  0.999998  0.805454  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1235 -0.151713  0.999999  0.809717  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1236 -0.157556  0.999999  0.813778  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#       x501  y501  z501  v501
# 0      NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...
# 1232   NaN   NaN   NaN   NaN
# 1233   NaN   NaN   NaN   NaN
# 1234   NaN   NaN   NaN   NaN
# 1235   NaN   NaN   NaN   NaN
# 1236   NaN   NaN   NaN   NaN
#
# [1237 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
X.dropna(axis=1, how='any', inplace=True)
y = df['class'] # target value

# %%
df.shape
# Out:
# (1715, 2004)

# %%
X.shape
X
# Out:
#             x1        y1        z1        v1        x2        y2        z2  \
# 0     0.451151  0.144746 -0.372693  0.999985  0.454345  0.124245 -0.369818
# 1     0.450804  0.143198 -0.405820  0.999985  0.454168  0.122036 -0.399079
# 2     0.448904  0.142284 -0.376282  0.999983  0.452525  0.121078 -0.377256
# 3     0.445280  0.138653 -0.368911  0.999983  0.448895  0.118170 -0.370954
# 4     0.441117  0.133836 -0.356226  0.999983  0.443727  0.114050 -0.360827
# ...        ...       ...       ...       ...       ...       ...       ...
# 1710  0.418214  0.529177 -0.059898  0.995948  0.422488  0.539639 -0.049005
# 1711  0.428246  0.573672 -0.071712  0.995005  0.428015  0.585898 -0.064052
# 1712  0.428274  0.609891 -0.047709  0.994327  0.432353  0.622005 -0.040413
# 1713  0.424670  0.589216 -0.046472  0.993130  0.426713  0.602443 -0.032074
# 1714  0.425220  0.608671 -0.118502  0.992998  0.426985  0.617375 -0.104623
#
#             v2        x3        y3  ...       z31       v31       x32  \
# 0     0.999962  0.458266  0.121006  ...  0.256507  0.938477  0.538574
# 1     0.999964  0.458237  0.118773  ...  0.396545  0.938166  0.539194
# 2     0.999961  0.456613  0.117747  ...  0.361362  0.938604  0.533816
# 3     0.999959  0.452974  0.114793  ...  0.340738  0.938976  0.533959
# 4     0.999958  0.447370  0.110689  ...  0.295900  0.938771  0.534148
# ...        ...       ...       ...  ...       ...       ...       ...
# 1710  0.995392  0.423687  0.542639  ...  0.144746  0.556589  0.257925
# 1711  0.994453  0.427078  0.586672  ...  0.185399  0.561116  0.259389
# 1712  0.993793  0.431292  0.621449  ...  0.212213  0.574322  0.260239
# 1713  0.992739  0.426249  0.602407  ...  0.085966  0.603577  0.259513
# 1714  0.992337  0.426723  0.617559  ...  0.139155  0.611259  0.282618
#
#            y32       z32       v32       x33       y33       z33       v33
# 0     0.851960 -0.139555  0.990209  0.426495  0.843518  0.152350  0.979981
# 1     0.855263 -0.073784  0.990764  0.426601  0.841865  0.304034  0.980356
# 2     0.856366 -0.013473  0.990910  0.425374  0.841821  0.271315  0.980604
# 3     0.857293 -0.167294  0.991287  0.424985  0.841714  0.262051  0.980607
# 4     0.857561 -0.243705  0.991671  0.421569  0.841631  0.189848  0.979968
# ...        ...       ...       ...       ...       ...       ...       ...
# 1710  0.289791  0.040756  0.482028  0.302063  0.240640  0.110213  0.491334
# 1711  0.337022 -0.034420  0.513900  0.345363  0.172958  0.159090  0.498276
# 1712  0.505201  0.002557  0.542629  0.342771  0.187784  0.189858  0.518408
# 1713  0.494020  0.142161  0.542211  0.324645  0.230710  0.043100  0.552732
# 1714  0.258051  0.152441  0.531929  0.325252  0.061474  0.082540  0.561092
#
# [1715 rows x 132 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 1016       Ollie
# 1542    Kickflip
# 454        Ollie
# 889        Ollie
# 222        Ollie
#           ...
# 520        Ollie
# 637        Ollie
# 1503    Kickflip
# 586        Ollie
# 1205       Ollie
# Name: class, Length: 515, dtype: object

# %% [markdown]
# ## 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# c:\users\roble\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Nollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Kickflip', 'Kickflip', 'Kickflip',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie',
#        'Nollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Kickflip', 'Kickflip', 'Ollie', 'Ollie', 'Nollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Kickflip', 'Nollie', 'Ollie', 'Kickflip',
#        'Ollie', 'Kickflip', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Nollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Nollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Kickflip', 'Ollie',
#        'Kickflip', 'Kickflip', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Nollie',
#        'Kickflip', 'Ollie', 'Kickflip', 'Kickflip', 'Ollie', 'Nollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Nollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Nollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Nollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Nollie',
#        'Ollie', 'Kickflip', 'Kickflip', 'Nollie', 'Ollie', 'Ollie',
#        'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Kickflip', 'Ollie', 'Ollie', 'Kickflip', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Kickflip',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Nollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Kickflip', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Nollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Nollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Kickflip', 'Kickflip', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie',
#        'Nollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Nollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Kickflip', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie'], dtype='<U8')

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9825242718446602
# rc 0.9650485436893204
# rf 0.996116504854369
# gb 1.0

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Nollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Kickflip', 'Kickflip',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie',
#        'Nollie', 'Kickflip', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Kickflip', 'Kickflip', 'Ollie', 'Ollie', 'Nollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Kickflip', 'Nollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Kickflip', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Nollie', 'Kickflip',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Kickflip',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Nollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Nollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Kickflip', 'Ollie', 'Kickflip', 'Kickflip', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Nollie', 'Kickflip', 'Ollie', 'Kickflip',
#        'Kickflip', 'Kickflip', 'Nollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Nollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Nollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Nollie',
#        'Ollie', 'Kickflip', 'Kickflip', 'Nollie', 'Ollie', 'Ollie',
#        'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Kickflip', 'Ollie',
#        'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Nollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Kickflip', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie', 'Kickflip', 'Ollie', 'Nollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Kickflip', 'Nollie', 'Ollie', 'Ollie',
#        'Kickflip', 'Ollie', 'Kickflip', 'Kickflip', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Ollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Nollie', 'Ollie', 'Ollie',
#        'Nollie', 'Ollie', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Nollie',
#        'Ollie', 'Ollie', 'Ollie', 'Ollie', 'Kickflip', 'Ollie',
#        'Kickflip', 'Kickflip', 'Ollie', 'Ollie', 'Ollie', 'Kickflip',
#        'Ollie', 'Ollie'], dtype=object)

# %%
y_test
# Out:
# 1016       Ollie
# 1542    Kickflip
# 454        Ollie
# 889        Ollie
# 222        Ollie
#           ...
# 520        Ollie
# 637        Ollie
# 1503    Kickflip
# 586        Ollie
# 1205       Ollie
# Name: class, Length: 515, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # 4. Make Detections with Model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (469, 191)
